# %% [markdown]
# # STORY

# %% [markdown]
#  Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.

# %% [markdown]
# # Questions Using SpaCy, NLTK, and TextBlob
#
#
# 1- Tokenization
#
# Use NLTK to tokenize the text into words.
#
#
# Tokenize the text into sentences using spaCy.
#
#
# 2- Named Entity Recognition (NER)
#
# Use spaCy to extract all named entities in the text.
#
#
# Identify and count all locations mentioned in the text using spaCy's NER.
#
#
# 3- Part of Speech (POS) Tagging
#
# Use TextBlob to tag the parts of speech for each word.
#
# Extract and list all nouns in the text using spaCy.
#
#
# 4- Stop Words Removal
#
# Use NLTK to remove stop words from the text and display the cleaned text.
#
#
# Use spaCy to remove stop words, then join and display the text without stop words.
#
#
# 5- Lemmatization
#
# Use spaCy to lemmatize each word in the text.
#
#
# Use NLTK to lemmatize only the verbs in the text.
#
# 6- Sentiment Analysis
#
# Use TextBlob to perform sentiment analysis on the entire text.
#
#
# Divide the text into sentences and analyze the sentiment of each sentence with TextBlob.
#
#
# 7- N-Grams
#
# Generate bigrams (two-word combinations) using NLTK.
#
#
# Generate trigrams (three-word combinations) using TextBlob.
#
#
# 8- Frequency Distribution
#
# Use NLTK to compute the frequency distribution of words in the text.
#
# Find the 5 most common nouns in the text using spaCy.
#
#
# 9- Dependency Parsing
#
# Extract and display dependency parse information for each sentence using spaCy.
#
# Visualize the dependency tree of the first sentence using spaCy’s displacy tool.
#
#
# 10- Phrase Matching
#
# Identify occurrences of the phrase "Maratha Empire" using spaCy's PhraseMatcher.
#
#
# Use spaCy’s Matcher to find patterns where Shivaji Maharaj is mentioned along with actions (verbs).
#
#
# 11- Sentence Similarity
#
#
# Calculate the similarity between the first two sentences of the text using spaCy.
#
#
# Use TextBlob to compute the similarity between sentences mentioning "Shivaji" and "Mughal Empire."
#
#
# 12- Translation
#
#
# Translate the first paragraph into Hindi using TextBlob.
#
#
# Translate the phrase "Hindavi Swarajya" into French using TextBlob.
#
#
# 13- Keyword Extraction
#
#
# Extract keywords using NLTK’s frequency distribution (common nouns and verbs).
#
#
# Use spaCy to identify and list unique keywords from the text (filter out stop words).
#
#
# 14- Coreference Resolution
#
#
#
# Use spaCy's neuralcoref extension to resolve pronouns in the text.
#
#
# Identify any instances where pronouns can be replaced with entity names for better clarity.
#
#
# 15- Sentiment Polarity Distribution
#
# Calculate and plot the sentiment polarity distribution for each sentence in the text using TextBlob.
#
#
# Identify and display the most positive and most negative sentences based on sentiment scores.
#
#
# 16- Extract Dates and Events
#
#
# Identify all dates mentioned in the text using spaCy.
#
# Use regex to find sentences related to events happening in specific years (e.g., 1674 or 1680).
#
#
# 17- Synonyms and Antonyms
#
# Use TextBlob's WordNet to find synonyms for "bravery," "justice," and "valor."
#
#
# Find antonyms of "oppression" and "invasion" using NLTK’s WordNet.
#
#
# 18- Spelling Correction
#
# Introduce 5 spelling errors in the text and use TextBlob to correct them.
#
#
# Identify words with potential spelling errors using TextBlob.
#
#
# 19- Extract Subject-Verb-Object Triples
#
# Use spaCy to extract subject-verb-object triples from the sentences.
#
#
# Identify and list sentences where "Shivaji" is the subject and a verb follows, using dependency parsing.
#
# 20- Create a Summary
#
# Summarize the text using TextBlob by extracting key sentences.
#
#
# Generate a summary using NLTK’s summarize function on cleaned text.

# %% [markdown]
# # 1. Tokenization
# Use NLTK to tokenize the text into words.
#
# Tokenize the text into sentences using spaCy.

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text ="Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture."

# %%
# Tokenize te text into word
word_tokens = word_tokenize(text)
print("word Token :" ,word_tokens)
# Out:
# word Token : ['Chhatrapati', 'Shivaji', 'Maharaj', 'was', 'born', 'on', 'February', '19', ',', '1630', ',', 'at', 'Shivneri', 'Fort', 'in', 'Maharashtra', ',', 'to', 'Shahaji', 'Bhonsle', ',', 'a', 'Maratha', 'general', ',', 'and', 'Jijabai', ',', 'who', 'deeply', 'influenced', 'Shivaji', 'with', 'her', 'teachings', 'on', 'dharma', ',', 'bravery', ',', 'and', 'justice', '.', 'From', 'an', 'early', 'age', ',', 'Shivaji', 'exhibited', 'remarkable', 'leadership', 'qualities', ',', 'forming', 'a', 'group', 'of', 'loyal', 'followers', 'and', 'honing', 'his', 'military', 'skills', 'in', 'the', 'rugged', 'terrain', 'of', 'the', 'Sahyadri', 'mountains', '.', 'He', 'grew', 'up', 'during', 'a', 'time', 'when', 'the', 'Mughal', 'Empire', 'under', 'Emperor', 'Aurangzeb', 'and', 'the', 'Deccan', 'Sultanates', 'were', 'vying', 'for', 'control', ',', 'often', 'oppressing', 'the', 'local', 'population', ',', 'which', 'deeply', 'disturbed', 'him', 'and', 'fueled', 'his', 'desire', 'to', 'establish', 'Swarajya', ',', 'or', 'self-rule', 'for', 'the', 'Marathas', '.', 'By', 'the', 'age', 'of', '16', ',', 'Shivaji', 'had', 'captured', 'his', 'first', 'fort', ',', 'Torna', ',', 'using', 'guerrilla', 'warfare', 'tactics', 'that', 'would', 'later', 'become', 'a', 'hallmark', 'of', 'his', 'military', 'strategy', '.', 'As', 'his', 'conquests', 'grew', ',', 'he', 'formed', 'alliances', 'with', 'local', 'leaders', ',', 'securing', 'key', 'forts', 'like', 'Raigad', ',', 'Kondana', ',', 'and', 'Purandar', ',', 'establishing', 'a', 'solid', 'territorial', 'base', 'in', 'western', 'India', '.', 'In', '1659', ',', 'he', 'faced', 'and', 'defeated', 'Afzal', 'Khan', ',', 'a', 'prominent', 'general', 'of', 'the', 'Bijapur', 'Sultanate', ',', 'solidifying', 'his', 'reputation', 'as', 'a', 'brave', 'and', 'tactical', 'leader', ';', 'this', 'victory', 'was', 'crucial', 'in', 'establishing', 'his', 'control', 'over', 'much', 'of', 'the', 'Deccan', '.', 'Shivaji', '’', 's', 'raids', 'on', 'Mughal', 'territories', 'and', 'his', 'escape', 'from', 'the', 'clutches', 'of', 'Aurangzeb', 'in', 'Agra', 'in', '1666', 'further', 'bolstered', 'his', 'legend', '.', 'He', 'realized', 'that', 'a', 'powerful', 'navy', 'was', 'crucial', 'to', 'safeguard', 'his', 'territories', 'from', 'foreign', 'invasions', ',', 'leading', 'him', 'to', 'develop', 'one', 'of', 'the', 'earliest', 'organized', 'naval', 'forces', 'in', 'India', ',', 'allowing', 'him', 'to', 'secure', 'coastal', 'areas', 'against', 'Portuguese', ',', 'British', ',', 'and', 'Siddis', 'forces', '.', 'In', '1674', ',', 'he', 'formally', 'crowned', 'himself', 'as', 'Chhatrapati', 'at', 'Raigad', 'Fort', ',', 'declaring', 'his', 'independence', 'and', 'establishing', 'the', 'Maratha', 'Empire', ',', 'thus', 'becoming', 'the', 'first', 'king', 'to', 'establish', 'Hindavi', 'Swarajya', ',', 'an', 'autonomous', 'kingdom', 'with', 'a', 'structured', 'administrative', 'framework', 'rooted', 'in', 'Indian', 'ethos', '.', 'Shivaji', '’', 's', 'administrative', 'system', 'was', 'highly', 'efficient', ',', 'and', 'he', 'emphasized', 'the', 'welfare', 'of', 'his', 'people', ',', 'setting', 'up', 'systems', 'to', 'reduce', 'corruption', 'and', 'create', 'a', 'fair', 'tax', 'structure', ';', 'his', 'Ashta', 'Pradhan', '(', 'Council', 'of', 'Eight', 'Ministers', ')', 'included', 'departments', 'for', 'finance', ',', 'internal', 'affairs', ',', 'foreign', 'policy', ',', 'and', 'military', 'to', 'ensure', 'smooth', 'governance', '.', 'Shivaji', 'showed', 'a', 'progressive', 'approach', 'towards', 'governance', ',', 'promoting', 'religious', 'tolerance', 'and', 'respecting', 'the', 'diversity', 'within', 'his', 'empire', ',', 'even', 'appointing', 'Muslims', 'to', 'key', 'positions', 'in', 'his', 'administration', 'and', 'banning', 'the', 'harassment', 'of', 'women', 'and', 'looting', 'of', 'religious', 'sites', '.', 'His', 'respect', 'for', 'women', 'and', 'his', 'advocacy', 'for', 'justice', 'inspired', 'trust', 'and', 'loyalty', 'among' ...

# %%
# Tokenizing words into sentences using spaCy
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Tokenize into sentences
doc = nlp(text)
sentence_tokens = [sent.text for sent in doc.sents]
print("Sentence Tokens:", sentence_tokens)
# Out:
# Sentence Tokens: ['Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice.', 'From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.', 'He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas.', 'By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.', 'As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.', 'In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan.', 'Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend.', 'He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces.', 'In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.', 'Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance.', 'Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.', 'His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.', 'Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses.', 'As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India.', 'Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.', 'His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.']

# %% [markdown]
#  # 2- Named Entity Recognition (NER)
# Use spaCy to extract all named entities in the text.
#
# Identify and count all locations mentioned in the text using spaCy's NER.

# %%
import spacy

# Load spaCy's English model for NER
nlp = spacy.load("en_core_web_sm")

# Perform NER
doc = nlp(text)
entities = [(ent.text, ent.label_) for ent in doc.ents]

# Display all entities
print("All Named Entities:", entities)

# Filter and count location entities
locations = [ent.text for ent in doc.ents if ent.label_ == "GPE"]  # "GPE" stands for Geopolitical Entity
location_count = len(locations)
print("Locations:", locations)
print("Number of Locations:", location_count)
# Out:
# All Named Entities: [('Chhatrapati Shivaji Maharaj', 'PERSON'), ('February 19, 1630', 'DATE'), ('Shivneri Fort', 'FAC'), ('Maharashtra', 'LOC'), ('Shahaji Bhonsle', 'PERSON'), ('Maratha', 'GPE'), ('Jijabai', 'GPE'), ('Shivaji', 'PERSON'), ('an early age', 'DATE'), ('Shivaji', 'PERSON'), ('Sahyadri', 'LOC'), ('the Mughal Empire', 'ORG'), ('Emperor Aurangzeb', 'ORG'), ('Swarajya', 'ORG'), ('Marathas', 'GPE'), ('the age of 16', 'DATE'), ('Shivaji', 'PERSON'), ('first', 'ORDINAL'), ('Torna', 'GPE'), ('Raigad', 'GPE'), ('Kondana', 'PERSON'), ('Purandar', 'PERSON'), ('India', 'GPE'), ('1659', 'DATE'), ('Afzal Khan', 'PERSON'), ('Deccan', 'NORP'), ('Aurangzeb', 'GPE'), ('Agra', 'GPE'), ('1666', 'DATE'), ('navy', 'ORG'), ('one', 'CARDINAL'), ('India', 'GPE'), ('Portuguese', 'NORP'), ('British', 'NORP'), ('Siddis', 'PERSON'), ('1674', 'DATE'), ('Chhatrapati', 'ORG'), ('Raigad Fort', 'FAC'), ('the Maratha Empire', 'LOC'), ('first', 'ORDINAL'), ('Hindavi Swarajya', 'PERSON'), ('Indian', 'NORP'), ('Ashta Pradhan (Council', 'ORG'), ('Muslims', 'NORP'), ('Shivaji Maharaj’s', 'PERSON'), ('Ganimi Kava', 'PERSON'), ('the Maratha Empire', 'ORG'), ('Maharashtra', 'ORG'), ('Maratha', 'PERSON'), ('India', 'GPE'), ('April 3, 1680', 'DATE'), ('Raigad Fort', 'FAC'), ('millions', 'CARDINAL'), ('the Maratha Empire’s', 'ORG'), ('India', 'GPE')]
# Locations: ['Maratha', 'Jijabai', 'Marathas', 'Torna', 'Raigad', 'India', 'Aurangzeb', 'Agra', 'India', 'India', 'India']
# Number of Locations: 11

# %% [markdown]
#  # 3- Part of Speech (POS) Tagging
# Use TextBlob to tag the parts of speech for each word.
#
# Extract and list all nouns in the text using spaCy.

# %%
# !pip install textblob
# !python -m textblob.download_corpora
# Out:
# Requirement already satisfied: textblob in c:\users\hp\anaconda3\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\hp\appdata\roaming\python\python312\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Finished.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!

# %%
from textblob import TextBlob

# Create a TextBlob object
#blob = TextBlob(text)

# Perform POS tagging
#pos_tags = blob.tags
#print("POS Tags:", pos_tags)


blob = TextBlob(text)
tags = blob.tags
print(tags)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\textblob\decorators.py:35, in requires_nltk_corpus.<locals>.decorated(*args, **kwargs)
#      34 try:
# ---> 35     return func(*args, **kwargs)
#      36 except LookupError as error:
#
# File ~\anaconda3\Lib\site-packages\textblob\en\taggers.py:35, in NLTKTagger.tag(self, text)
#      33     text = tb.TextBlob(text)
# ---> 35 return nltk.tag.pos_tag(text.tokens)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nltk\tag\__init__.py:168, in pos_tag(tokens, tagset, lang)
#     144 """
#     145 Use NLTK's currently recommended part of speech tagger to
#     146 tag the given list of tokens.
#    (...)
#     166 :rtype: list(tuple(str, str))
#     167 """
# --> 168 tagger = _get_tagger(lang)
#     169 return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nltk\tag\__init__.py:110, in _get_tagger(lang)
#     109 else:
# --> 110     tagger = PerceptronTagger()
#     111 return tagger
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nltk\tag\perceptron.py:183, in PerceptronTagger.__init__(self, load, lang)
#     182 if load:
# --> 183     self.load_from_json(lang)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nltk\tag\perceptron.py:273, in PerceptronTagger.load_from_json(self, lang)
#     271 def load_from_json(self, lang="eng"):
#     272     # Automatically find path to the tagger if location is not specified.
# --> 273     loc = find(f"taggers/averaged_perceptron_tagger_{lang}/")
#     274     with open(loc + TAGGER_JSONS[lang]["weights"]) as fin:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng/
#
#   Searched in:
#     - 'C:\\Users\\HP/nltk_data'
#     - 'C:\\Users\\HP\\anaconda3\\nltk_data'
#     - 'C:\\Users\\HP\\anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\HP\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\HP\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# The above exception was the direct cause of the following exception:
#
# MissingCorpusError                        Traceback (most recent call last)
# Cell In[24], line 12
#       3 # Create a TextBlob object
#       4 #blob = TextBlob(text)
#       5
#       6 # Perform POS tagging
#       7 #pos_tags = blob.tags
#       8 #print("POS Tags:", pos_tags)
#      11 blob = TextBlob(text)
# ---> 12 tags = blob.tags
#      13 print(tags)
#
# File ~\anaconda3\Lib\site-packages\textblob\decorators.py:23, in cached_property.__get__(self, obj, cls)
#      21 if obj is None:
#      22     return self
# ---> 23 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      24 return value
#
# File ~\anaconda3\Lib\site-packages\textblob\blob.py:497, in BaseBlob.pos_tags(self)
#     484 """Returns an list of tuples of the form (word, POS tag).
#     485
#     486 Example:
#    (...)
#     492 :rtype: list of tuples
#     493 """
#     494 if isinstance(self, TextBlob):
#     495     return [
#     496         val
# --> 497         for sublist in [s.pos_tags for s in self.sentences]
#     498         for val in sublist
#     499     ]
#     500 else:
#     501     return [
#     502         (Word(str(word), pos_tag=t), str(t))
#     503         for word, t in self.pos_tagger.tag(self)
#     504         if not PUNCTUATION_REGEX.match(str(t))
#     505     ]
#
# File ~\anaconda3\Lib\site-packages\textblob\decorators.py:23, in cached_property.__get__(self, obj, cls)
#      21 if obj is None:
#      22     return self
# ---> 23 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      24 return value
#
# File ~\anaconda3\Lib\site-packages\textblob\blob.py:503, in BaseBlob.pos_tags(self)
#     495     return [
#     496         val
#     497         for sublist in [s.pos_tags for s in self.sentences]
#     498         for val in sublist
#     499     ]
#     500 else:
#     501     return [
#     502         (Word(str(word), pos_tag=t), str(t))
# --> 503         for word, t in self.pos_tagger.tag(self)
#     504         if not PUNCTUATION_REGEX.match(str(t))
#     505     ]
#
# File ~\anaconda3\Lib\site-packages\textblob\decorators.py:37, in requires_nltk_corpus.<locals>.decorated(*args, **kwargs)
#      35     return func(*args, **kwargs)
#      36 except LookupError as error:
# ---> 37     raise MissingCorpusError() from error
#
# MissingCorpusError:
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# !pip install --upgrade textblob
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Requirement already satisfied: textblob in c:\users\hp\anaconda3\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\hp\appdata\roaming\python\python312\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)

# %%
# Extracting and listing all nouns 
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# Process the text
doc = nlp(text)

# Extract and list all nouns
nouns = [token.text for token in doc if token.pos_ == "NOUN"]
print("Nouns:", nouns)
# Out:
# Nouns: ['general', 'teachings', 'dharma', 'bravery', 'justice', 'age', 'leadership', 'qualities', 'group', 'followers', 'skills', 'terrain', 'mountains', 'time', 'control', 'population', 'desire', 'self', 'rule', 'age', 'fort', 'guerrilla', 'warfare', 'tactics', 'hallmark', 'strategy', 'conquests', 'alliances', 'leaders', 'forts', 'base', 'general', 'reputation', 'leader', 'victory', 'control', 'raids', 'territories', 'escape', 'clutches', 'legend', 'navy', 'territories', 'invasions', 'forces', 'areas', 'forces', 'independence', 'king', 'kingdom', 'framework', 'ethos', 'system', 'welfare', 'people', 'systems', 'corruption', 'tax', 'structure', 'departments', 'finance', 'affairs', 'policy', 'military', 'governance', 'approach', 'governance', 'tolerance', 'diversity', 'empire', 'positions', 'administration', 'harassment', 'women', 'looting', 'sites', 'respect', 'women', 'advocacy', 'justice', 'trust', 'loyalty', 'people', 'ruler', 'time', 'guerrilla', 'tactics', 'armies', 'empire', 'losses', 'fame', 'regions', 'forces', 'power', 'legacy', 'state', 'death', 'life', 'ideals', 'valor', 'respect', 'faiths', 'self', 'rule', 'millions', 'legacy', 'form', 'contributions', 'history', 'culture']

# %%
import nltk
nltk.data.path.append('C:/Users/HP/nltk_data')  # Change this path if necessary to a folder listed in your error

# %% [markdown]
#  # 4- Stop Words Removal
# Use NLTK to remove stop words from the text and display the cleaned text.
#
# Use spaCy to remove stop words, then join and display the text without stop words.

# %%
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def rem_stop(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    
    filtered_text = [word for word in word_tokens if word.lower() not in stop_words]
    filtered_text =  ' '.join(filtered_text)
    
    return filtered_text

print(rem_stop(text))
# Out:
# Chhatrapati Shivaji Maharaj born February 19 , 1630 , Shivneri Fort Maharashtra , Shahaji Bhonsle , Maratha general , Jijabai , deeply influenced Shivaji teachings dharma , bravery , justice . early age , Shivaji exhibited remarkable leadership qualities , forming group loyal followers honing military skills rugged terrain Sahyadri mountains . grew time Mughal Empire Emperor Aurangzeb Deccan Sultanates vying control , often oppressing local population , deeply disturbed fueled desire establish Swarajya , self-rule Marathas . age 16 , Shivaji captured first fort , Torna , using guerrilla warfare tactics would later become hallmark military strategy . conquests grew , formed alliances local leaders , securing key forts like Raigad , Kondana , Purandar , establishing solid territorial base western India . 1659 , faced defeated Afzal Khan , prominent general Bijapur Sultanate , solidifying reputation brave tactical leader ; victory crucial establishing control much Deccan . Shivaji ’ raids Mughal territories escape clutches Aurangzeb Agra 1666 bolstered legend . realized powerful navy crucial safeguard territories foreign invasions , leading develop one earliest organized naval forces India , allowing secure coastal areas Portuguese , British , Siddis forces . 1674 , formally crowned Chhatrapati Raigad Fort , declaring independence establishing Maratha Empire , thus becoming first king establish Hindavi Swarajya , autonomous kingdom structured administrative framework rooted Indian ethos . Shivaji ’ administrative system highly efficient , emphasized welfare people , setting systems reduce corruption create fair tax structure ; Ashta Pradhan ( Council Eight Ministers ) included departments finance , internal affairs , foreign policy , military ensure smooth governance . Shivaji showed progressive approach towards governance , promoting religious tolerance respecting diversity within empire , even appointing Muslims key positions administration banning harassment women looting religious sites . respect women advocacy justice inspired trust loyalty among people , making ideal ruler time . Shivaji Maharaj ’ guerrilla tactics , known “ Ganimi Kava , ” became legendary enabled outmaneuver much larger better-equipped armies repeatedly , allowing expand empire minimizing losses . fame grew , Maratha Empire began influence regions far beyond Maharashtra , Maratha forces eventually becoming significant power across India . Shivaji passed away April 3 , 1680 , Raigad Fort , leaving behind powerful legacy well-organized state continued expand death . life ideals—valor , respect faiths , self-rule—continue inspire millions , legacy endures form Maratha Empire ’ contributions India ’ history culture .

# %%
filtered_text = [token.text for token in doc if not token.is_stop]
filtered_text = ''.join(filtered_text)
print(filtered_text)
# Out:
# ChhatrapatiShivajiMaharajbornFebruary19,1630,ShivneriFortMaharashtra,ShahajiBhonsle,Marathageneral,Jijabai,deeplyinfluencedShivajiteachingsdharma,bravery,justice.earlyage,Shivajiexhibitedremarkableleadershipqualities,forminggrouployalfollowershoningmilitaryskillsruggedterrainSahyadrimountains.grewtimeMughalEmpireEmperorAurangzebDeccanSultanatesvyingcontrol,oppressinglocalpopulation,deeplydisturbedfueleddesireestablishSwarajya,self-ruleMarathas.age16,Shivajicapturedfort,Torna,guerrillawarfaretacticslaterhallmarkmilitarystrategy.conquestsgrew,formedallianceslocalleaders,securingkeyfortslikeRaigad,Kondana,Purandar,establishingsolidterritorialbasewesternIndia.1659,faceddefeatedAfzalKhan,prominentgeneralBijapurSultanate,solidifyingreputationbravetacticalleader;victorycrucialestablishingcontrolDeccan.ShivajiraidsMughalterritoriesescapeclutchesAurangzebAgra1666bolsteredlegend.realizedpowerfulnavycrucialsafeguardterritoriesforeigninvasions,leadingdevelopearliestorganizednavalforcesIndia,allowingsecurecoastalareasPortuguese,British,Siddisforces.1674,formallycrownedChhatrapatiRaigadFort,declaringindependenceestablishingMarathaEmpire,kingestablishHindaviSwarajya,autonomouskingdomstructuredadministrativeframeworkrootedIndianethos.Shivajiadministrativesystemhighlyefficient,emphasizedwelfarepeople,settingsystemsreducecorruptioncreatefairtaxstructure;AshtaPradhan(CouncilMinisters)includeddepartmentsfinance,internalaffairs,foreignpolicy,militaryensuresmoothgovernance.Shivajishowedprogressiveapproachgovernance,promotingreligioustolerancerespectingdiversityempire,appointingMuslimskeypositionsadministrationbanningharassmentwomenlootingreligioussites.respectwomenadvocacyjusticeinspiredtrustloyaltypeople,makingidealrulertime.ShivajiMaharajguerrillatactics,known“GanimiKava,”legendaryenabledoutmaneuverlargerbetter-equippedarmiesrepeatedly,allowingexpandempireminimizinglosses.famegrew,MarathaEmpirebeganinfluenceregionsfarMaharashtra,MarathaforceseventuallysignificantpowerIndia.ShivajipassedawayApril3,1680,RaigadFort,leavingpowerfullegacy-organizedstatecontinuedexpanddeath.lifeideals—valor,respectfaiths,self-rule—continueinspiremillions,legacyenduresformMarathaEmpirecontributionsIndiahistoryculture.

# %% [markdown]
#  # 5- Lemmatization
# Use spaCy to lemmatize each word in the text.
#
# Use NLTK to lemmatize only the verbs in the text.

# %%
lemma = [token.lemma_ for token in doc]
print(lemma)
# Out:
# ['Chhatrapati', 'Shivaji', 'Maharaj', 'be', 'bear', 'on', 'February', '19', ',', '1630', ',', 'at', 'Shivneri', 'Fort', 'in', 'Maharashtra', ',', 'to', 'Shahaji', 'Bhonsle', ',', 'a', 'Maratha', 'general', ',', 'and', 'Jijabai', ',', 'who', 'deeply', 'influence', 'Shivaji', 'with', 'her', 'teaching', 'on', 'dharma', ',', 'bravery', ',', 'and', 'justice', '.', 'from', 'an', 'early', 'age', ',', 'Shivaji', 'exhibit', 'remarkable', 'leadership', 'quality', ',', 'form', 'a', 'group', 'of', 'loyal', 'follower', 'and', 'hone', 'his', 'military', 'skill', 'in', 'the', 'rugged', 'terrain', 'of', 'the', 'Sahyadri', 'mountain', '.', 'he', 'grow', 'up', 'during', 'a', 'time', 'when', 'the', 'Mughal', 'Empire', 'under', 'Emperor', 'Aurangzeb', 'and', 'the', 'Deccan', 'Sultanates', 'be', 'vie', 'for', 'control', ',', 'often', 'oppress', 'the', 'local', 'population', ',', 'which', 'deeply', 'disturb', 'he', 'and', 'fuel', 'his', 'desire', 'to', 'establish', 'Swarajya', ',', 'or', 'self', '-', 'rule', 'for', 'the', 'Marathas', '.', 'by', 'the', 'age', 'of', '16', ',', 'Shivaji', 'have', 'capture', 'his', 'first', 'fort', ',', 'Torna', ',', 'use', 'guerrilla', 'warfare', 'tactic', 'that', 'would', 'later', 'become', 'a', 'hallmark', 'of', 'his', 'military', 'strategy', '.', 'as', 'his', 'conquest', 'grow', ',', 'he', 'form', 'alliance', 'with', 'local', 'leader', ',', 'secure', 'key', 'fort', 'like', 'Raigad', ',', 'Kondana', ',', 'and', 'Purandar', ',', 'establish', 'a', 'solid', 'territorial', 'base', 'in', 'western', 'India', '.', 'in', '1659', ',', 'he', 'face', 'and', 'defeat', 'Afzal', 'Khan', ',', 'a', 'prominent', 'general', 'of', 'the', 'Bijapur', 'Sultanate', ',', 'solidify', 'his', 'reputation', 'as', 'a', 'brave', 'and', 'tactical', 'leader', ';', 'this', 'victory', 'be', 'crucial', 'in', 'establish', 'his', 'control', 'over', 'much', 'of', 'the', 'Deccan', '.', 'Shivaji', '’s', 'raid', 'on', 'Mughal', 'territory', 'and', 'his', 'escape', 'from', 'the', 'clutch', 'of', 'Aurangzeb', 'in', 'Agra', 'in', '1666', 'far', 'bolster', 'his', 'legend', '.', 'he', 'realize', 'that', 'a', 'powerful', 'navy', 'be', 'crucial', 'to', 'safeguard', 'his', 'territory', 'from', 'foreign', 'invasion', ',', 'lead', 'he', 'to', 'develop', 'one', 'of', 'the', 'early', 'organize', 'naval', 'force', 'in', 'India', ',', 'allow', 'he', 'to', 'secure', 'coastal', 'area', 'against', 'portuguese', ',', 'british', ',', 'and', 'Siddis', 'force', '.', 'in', '1674', ',', 'he', 'formally', 'crown', 'himself', 'as', 'Chhatrapati', 'at', 'Raigad', 'Fort', ',', 'declare', 'his', 'independence', 'and', 'establish', 'the', 'Maratha', 'Empire', ',', 'thus', 'become', 'the', 'first', 'king', 'to', 'establish', 'Hindavi', 'Swarajya', ',', 'an', 'autonomous', 'kingdom', 'with', 'a', 'structured', 'administrative', 'framework', 'root', 'in', 'indian', 'ethos', '.', 'Shivaji', '’s', 'administrative', 'system', 'be', 'highly', 'efficient', ',', 'and', 'he', 'emphasize', 'the', 'welfare', 'of', 'his', 'people', ',', 'set', 'up', 'system', 'to', 'reduce', 'corruption', 'and', 'create', 'a', 'fair', 'tax', 'structure', ';', 'his', 'Ashta', 'Pradhan', '(', 'Council', 'of', 'Eight', 'Ministers', ')', 'include', 'department', 'for', 'finance', ',', 'internal', 'affair', ',', 'foreign', 'policy', ',', 'and', 'military', 'to', 'ensure', 'smooth', 'governance', '.', 'Shivaji', 'show', 'a', 'progressive', 'approach', 'towards', 'governance', ',', 'promote', 'religious', 'tolerance', 'and', 'respect', 'the', 'diversity', 'within', 'his', 'empire', ',', 'even', 'appoint', 'Muslims', 'to', 'key', 'position', 'in', 'his', 'administration', 'and', 'ban', 'the', 'harassment', 'of', 'woman', 'and', 'looting', 'of', 'religious', 'site', '.', 'his', 'respect', 'for', 'woman', 'and', 'his', 'advocacy', 'for', 'justice', 'inspire', 'trust', 'and', 'loyalty', 'among', 'his', 'people', ',', 'make', 'he', 'an', 'ideal', 'ruler', 'for', 'his', 'time', '.', 'Shivaji', 'Maharaj', '’s', 'guerrilla', 'ta ...

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import pos_tag

lemmatizer = WordNetLemmatizer()

def lemmatize_verbs(text):
  words = word_tokenize(text)
  lemmas = []
  for word, tag in pos_tag(words):
    if tag.startswith('VB'):
      lemma = lemmatizer.lemmatize(word, pos='v')
    else:
      lemma = word
    lemmas.append(lemma)
  return ' '.join(lemmas)

lemmatized_text = lemmatize_verbs(text)
print(lemmatized_text)
# Out:
# Chhatrapati Shivaji Maharaj be bear on February 19 , 1630 , at Shivneri Fort in Maharashtra , to Shahaji Bhonsle , a Maratha general , and Jijabai , who deeply influence Shivaji with her teachings on dharma , bravery , and justice . From an early age , Shivaji exhibit remarkable leadership qualities , form a group of loyal followers and hone his military skills in the rugged terrain of the Sahyadri mountains . He grow up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates be vie for control , often oppress the local population , which deeply disturb him and fuel his desire to establish Swarajya , or self-rule for the Marathas . By the age of 16 , Shivaji have capture his first fort , Torna , use guerrilla warfare tactics that would later become a hallmark of his military strategy . As his conquests grow , he form alliances with local leaders , secure key forts like Raigad , Kondana , and Purandar , establish a solid territorial base in western India . In 1659 , he face and defeat Afzal Khan , a prominent general of the Bijapur Sultanate , solidify his reputation as a brave and tactical leader ; this victory be crucial in establish his control over much of the Deccan . Shivaji ’ s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolster his legend . He realize that a powerful navy be crucial to safeguard his territories from foreign invasions , lead him to develop one of the earliest organize naval forces in India , allow him to secure coastal areas against Portuguese , British , and Siddis forces . In 1674 , he formally crown himself as Chhatrapati at Raigad Fort , declare his independence and establish the Maratha Empire , thus become the first king to establish Hindavi Swarajya , an autonomous kingdom with a structured administrative framework root in Indian ethos . Shivaji ’ s administrative system be highly efficient , and he emphasize the welfare of his people , set up systems to reduce corruption and create a fair tax structure ; his Ashta Pradhan ( Council of Eight Ministers ) include departments for finance , internal affairs , foreign policy , and military to ensure smooth governance . Shivaji show a progressive approach towards governance , promote religious tolerance and respect the diversity within his empire , even appoint Muslims to key positions in his administration and ban the harassment of women and looting of religious sites . His respect for women and his advocacy for justice inspire trust and loyalty among his people , make him an ideal ruler for his time . Shivaji Maharaj ’ s guerrilla tactics , know as “ Ganimi Kava , ” become legendary and enable him to outmaneuver much larger and better-equipped armies repeatedly , allow him to expand his empire while minimize losses . As his fame grow , the Maratha Empire begin to influence regions far beyond Maharashtra , with Maratha forces eventually become a significant power across India . Shivaji pass away on April 3 , 1680 , at Raigad Fort , leave behind a powerful legacy and a well-organized state that continue to expand after his death . His life and ideals—valor , respect for all faiths , and self-rule—continue to inspire millions , and his legacy endure in the form of the Maratha Empire ’ s contributions to India ’ s history and culture .

# %%
  import nltk
  nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %% [markdown]
# # 6- Sentiment Analysis
# Use TextBlob to perform sentiment analysis on the entire text.
#
# Divide the text into sentences and analyze the sentiment of each sentence with TextBlob.

# %%
from textblob import TextBlob

blob = TextBlob(text)
sentiment = blob.sentiment
print(sentiment)
# Out:
# Sentiment(polarity=0.15890070921985816, subjectivity=0.5364893617021277)

# %%
sentences = blob.sentences

for sentence in sentences:
    print(sentence)
    print(sentence.sentiment)
    print()
# Out:
# Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice.
# Sentiment(polarity=0.02500000000000001, subjectivity=0.45)
#
# From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.
# Sentiment(polarity=0.2708333333333333, subjectivity=0.49583333333333335)
#
# He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas.
# Sentiment(polarity=0.0, subjectivity=0.2)
#
# By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.
# Sentiment(polarity=0.049999999999999996, subjectivity=0.14444444444444446)
#
# As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.
# Sentiment(polarity=-0.16, subjectivity=0.42000000000000004)
#
# In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan.
# Sentiment(polarity=0.31, subjectivity=0.74)
#
# Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend.
# Sentiment(polarity=0.0, subjectivity=0.5)
#
# He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces.
# Sentiment(polarity=0.11499999999999999, subjectivity=0.545)
#
# In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.
# Sentiment(polarity=0.3666666666666667, subjectivity=0.6277777777777778)
#
# Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance.
# Sentiment(polarity=0.17250000000000001, subjectivity=0.36083333333333334)
#
# Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.
# Sentiment(polarity=0.0, subjectivity=0.5)
#
# His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.
# Sentiment(polarity=0.9, subjectivity=1.0)
#
# Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses.
# Sentiment(polarity=0.5, subjectivity=0.75)
#
# As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India.
# Sentiment(polarity=0.30833333333333335, subjectivity=0.9083333333333333)
#
# Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.
# Sentiment(polarity=-0.05000000000000002, subjectivity=0.85)
#
# His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.
# Sentiment(polarity=0.0, subjectivity=0.0)

# %% [markdown]
# # 7- N-Grams
# Generate bigrams (two-word combinations) using NLTK.
#
# Generate trigrams (three-word combinations) using TextBlob.

# %%
from nltk.util import ngrams
word_tokens = word_tokenize(text)
bigrams = ngrams(word_tokens, 2)
print(list(bigrams))
# Out:
# [('Chhatrapati', 'Shivaji'), ('Shivaji', 'Maharaj'), ('Maharaj', 'was'), ('was', 'born'), ('born', 'on'), ('on', 'February'), ('February', '19'), ('19', ','), (',', '1630'), ('1630', ','), (',', 'at'), ('at', 'Shivneri'), ('Shivneri', 'Fort'), ('Fort', 'in'), ('in', 'Maharashtra'), ('Maharashtra', ','), (',', 'to'), ('to', 'Shahaji'), ('Shahaji', 'Bhonsle'), ('Bhonsle', ','), (',', 'a'), ('a', 'Maratha'), ('Maratha', 'general'), ('general', ','), (',', 'and'), ('and', 'Jijabai'), ('Jijabai', ','), (',', 'who'), ('who', 'deeply'), ('deeply', 'influenced'), ('influenced', 'Shivaji'), ('Shivaji', 'with'), ('with', 'her'), ('her', 'teachings'), ('teachings', 'on'), ('on', 'dharma'), ('dharma', ','), (',', 'bravery'), ('bravery', ','), (',', 'and'), ('and', 'justice'), ('justice', '.'), ('.', 'From'), ('From', 'an'), ('an', 'early'), ('early', 'age'), ('age', ','), (',', 'Shivaji'), ('Shivaji', 'exhibited'), ('exhibited', 'remarkable'), ('remarkable', 'leadership'), ('leadership', 'qualities'), ('qualities', ','), (',', 'forming'), ('forming', 'a'), ('a', 'group'), ('group', 'of'), ('of', 'loyal'), ('loyal', 'followers'), ('followers', 'and'), ('and', 'honing'), ('honing', 'his'), ('his', 'military'), ('military', 'skills'), ('skills', 'in'), ('in', 'the'), ('the', 'rugged'), ('rugged', 'terrain'), ('terrain', 'of'), ('of', 'the'), ('the', 'Sahyadri'), ('Sahyadri', 'mountains'), ('mountains', '.'), ('.', 'He'), ('He', 'grew'), ('grew', 'up'), ('up', 'during'), ('during', 'a'), ('a', 'time'), ('time', 'when'), ('when', 'the'), ('the', 'Mughal'), ('Mughal', 'Empire'), ('Empire', 'under'), ('under', 'Emperor'), ('Emperor', 'Aurangzeb'), ('Aurangzeb', 'and'), ('and', 'the'), ('the', 'Deccan'), ('Deccan', 'Sultanates'), ('Sultanates', 'were'), ('were', 'vying'), ('vying', 'for'), ('for', 'control'), ('control', ','), (',', 'often'), ('often', 'oppressing'), ('oppressing', 'the'), ('the', 'local'), ('local', 'population'), ('population', ','), (',', 'which'), ('which', 'deeply'), ('deeply', 'disturbed'), ('disturbed', 'him'), ('him', 'and'), ('and', 'fueled'), ('fueled', 'his'), ('his', 'desire'), ('desire', 'to'), ('to', 'establish'), ('establish', 'Swarajya'), ('Swarajya', ','), (',', 'or'), ('or', 'self-rule'), ('self-rule', 'for'), ('for', 'the'), ('the', 'Marathas'), ('Marathas', '.'), ('.', 'By'), ('By', 'the'), ('the', 'age'), ('age', 'of'), ('of', '16'), ('16', ','), (',', 'Shivaji'), ('Shivaji', 'had'), ('had', 'captured'), ('captured', 'his'), ('his', 'first'), ('first', 'fort'), ('fort', ','), (',', 'Torna'), ('Torna', ','), (',', 'using'), ('using', 'guerrilla'), ('guerrilla', 'warfare'), ('warfare', 'tactics'), ('tactics', 'that'), ('that', 'would'), ('would', 'later'), ('later', 'become'), ('become', 'a'), ('a', 'hallmark'), ('hallmark', 'of'), ('of', 'his'), ('his', 'military'), ('military', 'strategy'), ('strategy', '.'), ('.', 'As'), ('As', 'his'), ('his', 'conquests'), ('conquests', 'grew'), ('grew', ','), (',', 'he'), ('he', 'formed'), ('formed', 'alliances'), ('alliances', 'with'), ('with', 'local'), ('local', 'leaders'), ('leaders', ','), (',', 'securing'), ('securing', 'key'), ('key', 'forts'), ('forts', 'like'), ('like', 'Raigad'), ('Raigad', ','), (',', 'Kondana'), ('Kondana', ','), (',', 'and'), ('and', 'Purandar'), ('Purandar', ','), (',', 'establishing'), ('establishing', 'a'), ('a', 'solid'), ('solid', 'territorial'), ('territorial', 'base'), ('base', 'in'), ('in', 'western'), ('western', 'India'), ('India', '.'), ('.', 'In'), ('In', '1659'), ('1659', ','), (',', 'he'), ('he', 'faced'), ('faced', 'and'), ('and', 'defeated'), ('defeated', 'Afzal'), ('Afzal', 'Khan'), ('Khan', ','), (',', 'a'), ('a', 'prominent'), ('prominent', 'general'), ('general', 'of'), ('of', 'the'), ('the', 'Bijapur'), ('Bijapur', 'Sultanate'), ('Sultanate', ','), (',', 'solidifying'), ('solidifying', 'his'), ('his', 'reputation'), ('reputation', 'as'), ('as', 'a'), ('a', 'brave'), ('brave', 'and'), ('and', 'tactical'), ('tactical', 'lead ...

# %%
#Generate trigrams (three-word combinations) using TextBlob.

words = blob.words
trigrams = [(words[i], words[i+1], words[i+2]) for i in range(len(words)-2)]
print(trigrams)
# Out:
# [('Chhatrapati', 'Shivaji', 'Maharaj'), ('Shivaji', 'Maharaj', 'was'), ('Maharaj', 'was', 'born'), ('was', 'born', 'on'), ('born', 'on', 'February'), ('on', 'February', '19'), ('February', '19', '1630'), ('19', '1630', 'at'), ('1630', 'at', 'Shivneri'), ('at', 'Shivneri', 'Fort'), ('Shivneri', 'Fort', 'in'), ('Fort', 'in', 'Maharashtra'), ('in', 'Maharashtra', 'to'), ('Maharashtra', 'to', 'Shahaji'), ('to', 'Shahaji', 'Bhonsle'), ('Shahaji', 'Bhonsle', 'a'), ('Bhonsle', 'a', 'Maratha'), ('a', 'Maratha', 'general'), ('Maratha', 'general', 'and'), ('general', 'and', 'Jijabai'), ('and', 'Jijabai', 'who'), ('Jijabai', 'who', 'deeply'), ('who', 'deeply', 'influenced'), ('deeply', 'influenced', 'Shivaji'), ('influenced', 'Shivaji', 'with'), ('Shivaji', 'with', 'her'), ('with', 'her', 'teachings'), ('her', 'teachings', 'on'), ('teachings', 'on', 'dharma'), ('on', 'dharma', 'bravery'), ('dharma', 'bravery', 'and'), ('bravery', 'and', 'justice'), ('and', 'justice', 'From'), ('justice', 'From', 'an'), ('From', 'an', 'early'), ('an', 'early', 'age'), ('early', 'age', 'Shivaji'), ('age', 'Shivaji', 'exhibited'), ('Shivaji', 'exhibited', 'remarkable'), ('exhibited', 'remarkable', 'leadership'), ('remarkable', 'leadership', 'qualities'), ('leadership', 'qualities', 'forming'), ('qualities', 'forming', 'a'), ('forming', 'a', 'group'), ('a', 'group', 'of'), ('group', 'of', 'loyal'), ('of', 'loyal', 'followers'), ('loyal', 'followers', 'and'), ('followers', 'and', 'honing'), ('and', 'honing', 'his'), ('honing', 'his', 'military'), ('his', 'military', 'skills'), ('military', 'skills', 'in'), ('skills', 'in', 'the'), ('in', 'the', 'rugged'), ('the', 'rugged', 'terrain'), ('rugged', 'terrain', 'of'), ('terrain', 'of', 'the'), ('of', 'the', 'Sahyadri'), ('the', 'Sahyadri', 'mountains'), ('Sahyadri', 'mountains', 'He'), ('mountains', 'He', 'grew'), ('He', 'grew', 'up'), ('grew', 'up', 'during'), ('up', 'during', 'a'), ('during', 'a', 'time'), ('a', 'time', 'when'), ('time', 'when', 'the'), ('when', 'the', 'Mughal'), ('the', 'Mughal', 'Empire'), ('Mughal', 'Empire', 'under'), ('Empire', 'under', 'Emperor'), ('under', 'Emperor', 'Aurangzeb'), ('Emperor', 'Aurangzeb', 'and'), ('Aurangzeb', 'and', 'the'), ('and', 'the', 'Deccan'), ('the', 'Deccan', 'Sultanates'), ('Deccan', 'Sultanates', 'were'), ('Sultanates', 'were', 'vying'), ('were', 'vying', 'for'), ('vying', 'for', 'control'), ('for', 'control', 'often'), ('control', 'often', 'oppressing'), ('often', 'oppressing', 'the'), ('oppressing', 'the', 'local'), ('the', 'local', 'population'), ('local', 'population', 'which'), ('population', 'which', 'deeply'), ('which', 'deeply', 'disturbed'), ('deeply', 'disturbed', 'him'), ('disturbed', 'him', 'and'), ('him', 'and', 'fueled'), ('and', 'fueled', 'his'), ('fueled', 'his', 'desire'), ('his', 'desire', 'to'), ('desire', 'to', 'establish'), ('to', 'establish', 'Swarajya'), ('establish', 'Swarajya', 'or'), ('Swarajya', 'or', 'self-rule'), ('or', 'self-rule', 'for'), ('self-rule', 'for', 'the'), ('for', 'the', 'Marathas'), ('the', 'Marathas', 'By'), ('Marathas', 'By', 'the'), ('By', 'the', 'age'), ('the', 'age', 'of'), ('age', 'of', '16'), ('of', '16', 'Shivaji'), ('16', 'Shivaji', 'had'), ('Shivaji', 'had', 'captured'), ('had', 'captured', 'his'), ('captured', 'his', 'first'), ('his', 'first', 'fort'), ('first', 'fort', 'Torna'), ('fort', 'Torna', 'using'), ('Torna', 'using', 'guerrilla'), ('using', 'guerrilla', 'warfare'), ('guerrilla', 'warfare', 'tactics'), ('warfare', 'tactics', 'that'), ('tactics', 'that', 'would'), ('that', 'would', 'later'), ('would', 'later', 'become'), ('later', 'become', 'a'), ('become', 'a', 'hallmark'), ('a', 'hallmark', 'of'), ('hallmark', 'of', 'his'), ('of', 'his', 'military'), ('his', 'military', 'strategy'), ('military', 'strategy', 'As'), ('strategy', 'As', 'his'), ('As', 'his', 'conquests'), ('his', 'conquests', 'grew'), ('conquests', 'grew', 'he'), ('grew', 'he', 'formed'), ('he', 'formed', 'alliances'), ('formed', 'allia ...

# %% [markdown]
# # 8- Frequency Distribution
# Use NLTK to compute the frequency distribution of words in the text.
#
# Find the 5 most common nouns in the text using spaCy.

# %%
# Use NLTK to compute the frequency distribution of words in the text.

from nltk.probability import FreqDist


word_tokens = word_tokenize(text)
word_freq_dist = FreqDist(word_tokens)
print("-"*40)
print(word_freq_dist)
print("-"*40)

print("*"*40)
print("Top 5 common noun is :- ")
for word, frequency in word_freq_dist.most_common(15):
    print(f"{word}: {frequency}")
print("*"*40)
# Out:
# ----------------------------------------
# <FreqDist with 307 samples and 595 outcomes>
# ----------------------------------------
# ****************************************
# Top 5 common noun is :-
# ,: 51
# and: 26
# his: 22
# the: 19
# .: 16
# to: 15
# a: 14
# of: 13
# in: 10
# Shivaji: 9
# for: 7
# him: 6
# Maratha: 5
# ’: 5
# s: 5
# ****************************************

# %% [markdown]
#  # 9- Dependency Parsing
# Extract and display dependency parse information for each sentence using spaCy.
#
# Visualize the dependency tree of the first sentence using spaCy’s displacy tool.

# %%
# Extract and display dependency parse information for each sentence using spaCy.
sentences = nlp(text).sents
for sentence in sentences:
    print(sentence)
    print([(token.text, token.dep_, token.head.text, token.head.pos_) for token in sentence])
    print()
# Out:
# Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice.
# [('Chhatrapati', 'compound', 'Maharaj', 'PROPN'), ('Shivaji', 'compound', 'Maharaj', 'PROPN'), ('Maharaj', 'nsubjpass', 'born', 'VERB'), ('was', 'auxpass', 'born', 'VERB'), ('born', 'ROOT', 'born', 'VERB'), ('on', 'prep', 'born', 'VERB'), ('February', 'pobj', 'on', 'ADP'), ('19', 'nummod', 'February', 'PROPN'), (',', 'punct', 'February', 'PROPN'), ('1630', 'nummod', 'February', 'PROPN'), (',', 'punct', 'February', 'PROPN'), ('at', 'prep', 'born', 'VERB'), ('Shivneri', 'compound', 'Fort', 'PROPN'), ('Fort', 'pobj', 'at', 'ADP'), ('in', 'prep', 'Fort', 'PROPN'), ('Maharashtra', 'pobj', 'in', 'ADP'), (',', 'punct', 'born', 'VERB'), ('to', 'prep', 'born', 'VERB'), ('Shahaji', 'compound', 'Bhonsle', 'PROPN'), ('Bhonsle', 'pobj', 'to', 'ADP'), (',', 'punct', 'Bhonsle', 'PROPN'), ('a', 'det', 'general', 'NOUN'), ('Maratha', 'compound', 'general', 'NOUN'), ('general', 'appos', 'Bhonsle', 'PROPN'), (',', 'punct', 'Bhonsle', 'PROPN'), ('and', 'cc', 'Bhonsle', 'PROPN'), ('Jijabai', 'conj', 'Bhonsle', 'PROPN'), (',', 'punct', 'Jijabai', 'PROPN'), ('who', 'nsubj', 'influenced', 'VERB'), ('deeply', 'advmod', 'influenced', 'VERB'), ('influenced', 'relcl', 'Jijabai', 'PROPN'), ('Shivaji', 'dobj', 'influenced', 'VERB'), ('with', 'prep', 'influenced', 'VERB'), ('her', 'poss', 'teachings', 'NOUN'), ('teachings', 'pobj', 'with', 'ADP'), ('on', 'prep', 'teachings', 'NOUN'), ('dharma', 'pobj', 'on', 'ADP'), (',', 'punct', 'dharma', 'NOUN'), ('bravery', 'conj', 'dharma', 'NOUN'), (',', 'punct', 'bravery', 'NOUN'), ('and', 'cc', 'bravery', 'NOUN'), ('justice', 'conj', 'bravery', 'NOUN'), ('.', 'punct', 'born', 'VERB')]
#
# From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.
# [('From', 'prep', 'exhibited', 'VERB'), ('an', 'det', 'age', 'NOUN'), ('early', 'amod', 'age', 'NOUN'), ('age', 'pobj', 'From', 'ADP'), (',', 'punct', 'exhibited', 'VERB'), ('Shivaji', 'nsubj', 'exhibited', 'VERB'), ('exhibited', 'ROOT', 'exhibited', 'VERB'), ('remarkable', 'amod', 'qualities', 'NOUN'), ('leadership', 'compound', 'qualities', 'NOUN'), ('qualities', 'dobj', 'exhibited', 'VERB'), (',', 'punct', 'exhibited', 'VERB'), ('forming', 'advcl', 'exhibited', 'VERB'), ('a', 'det', 'group', 'NOUN'), ('group', 'dobj', 'forming', 'VERB'), ('of', 'prep', 'group', 'NOUN'), ('loyal', 'amod', 'followers', 'NOUN'), ('followers', 'pobj', 'of', 'ADP'), ('and', 'cc', 'forming', 'VERB'), ('honing', 'conj', 'forming', 'VERB'), ('his', 'poss', 'skills', 'NOUN'), ('military', 'amod', 'skills', 'NOUN'), ('skills', 'dobj', 'honing', 'VERB'), ('in', 'prep', 'honing', 'VERB'), ('the', 'det', 'terrain', 'NOUN'), ('rugged', 'amod', 'terrain', 'NOUN'), ('terrain', 'pobj', 'in', 'ADP'), ('of', 'prep', 'terrain', 'NOUN'), ('the', 'det', 'mountains', 'NOUN'), ('Sahyadri', 'compound', 'mountains', 'NOUN'), ('mountains', 'pobj', 'of', 'ADP'), ('.', 'punct', 'exhibited', 'VERB')]
#
# He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas.
# [('He', 'nsubj', 'grew', 'VERB'), ('grew', 'ROOT', 'grew', 'VERB'), ('up', 'prt', 'grew', 'VERB'), ('during', 'prep', 'grew', 'VERB'), ('a', 'det', 'time', 'NOUN'), ('time', 'pobj', 'during', 'ADP'), ('when', 'advmod', 'vying', 'VERB'), ('the', 'det', 'Empire', 'PROPN'), ('Mughal', 'compound', 'Empire', 'PROPN'), ('Empire', 'nsubj', 'vying', 'VERB'), ('under', 'prep', 'Empire', 'PROPN'), ('Emperor', 'compound', 'Aurangzeb', 'PROPN'), ('Aurangzeb', 'pobj', 'under', 'ADP'), ('and', 'cc', 'Aurangzeb', 'PROPN'), ('the', 'det', 'Sultanates', 'PROPN'), ('Deccan', 'compound', 'Sultanates', 'PROPN'), ('Sultanates', 'conj', 'Aurangzeb', 'PROPN'), ('were', 'aux', 'vying', 'VERB'), ('vying', 'relcl', 'time', 'NOUN'), ('for', 'prep', 'vying', 'VERB'), ('control', 'pobj', 'for', 'ADP'), (',', 'punct', 'grew', 'VERB'), ('often', 'advmod', 'oppressing', 'VERB'), ('oppressing', 'advcl', 'grew', 'VERB'), ('the', 'det', 'population', 'NOUN'), ('local', 'amod', 'population', 'NOUN'), ('population', 'dobj', 'oppressing', 'VERB'), (',', 'punct', 'population', 'NOUN'), ('which', 'nsubj', 'disturbed', 'VERB'), ('deeply', 'advmod', 'disturbed', 'VERB'), ('disturbed', 'relcl', 'population', 'NOUN'), ('him', 'dobj', 'disturbed', 'VERB'), ('and', 'cc', 'disturbed', 'VERB'), ('fueled', 'conj', 'disturbed', 'VERB'), ('his', 'poss', 'desire', 'NOUN'), ('desire', 'dobj', 'fueled', 'VERB'), ('to', 'aux', 'establish', 'VERB'), ('establish', 'acl', 'desire', 'NOUN'), ('Swarajya', 'dobj', 'establish', 'VERB'), (',', 'punct', 'Swarajya', 'PROPN'), ('or', 'cc', 'Swarajya', 'PROPN'), ('self', 'compound', 'rule', 'NOUN'), ('-', 'punct', 'rule', 'NOUN'), ('rule', 'conj', 'Swarajya', 'PROPN'), ('for', 'prep', 'establish', 'VERB'), ('the', 'det', 'Marathas', 'PROPN'), ('Marathas', 'pobj', 'for', 'ADP'), ('.', 'punct', 'grew', 'VERB')]
#
# By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.
# [('By', 'prep', 'captured', 'VERB'), ('the', 'det', 'age', 'NOUN'), ('age', 'pobj', 'By', 'ADP'), ('of', 'prep', 'age', 'NOUN'), ('16', 'pobj', 'of', 'ADP'), (',', 'punct', 'captured', 'VERB'), ('Shivaji', 'nsubj', 'captured', 'VERB'), ('had', 'aux', 'captured', 'VERB'), ('captured', 'ROOT', 'captured', 'VERB'), ('his', 'poss', 'fort', 'NOUN'), ('first', 'amod', 'fort', 'NOUN'), ('fort', 'dobj', 'captured', 'VERB'), (',', 'punct', 'fort', 'NOUN'), ('Torna', 'appos', 'fort', 'NOUN'), (',', 'punct', 'fort', 'NOUN'), ('using', 'advcl', 'captured', 'VERB'), ('guerrilla', 'compound', 'warfare', 'NOUN'), ('warfare', 'compound', 'tactics', 'NOUN'), ('tactics', 'dobj', 'using', 'VERB'), ('that', 'nsubj', 'become', 'VERB'), ('would', 'aux', 'become', 'VERB'), ('later', 'advmod', 'become', 'VERB'), ('become', 'ccomp', 'using', 'VERB'), ('a', 'det', 'hallmark', 'NOUN'), ('hallmark', 'attr', 'become', 'VERB'), ('of', 'prep', 'hallmark', 'NOUN'), ('his', 'poss', 'strategy', 'NOUN'), ('military', 'amod', 'strategy', 'NOUN'), ('strategy', 'pobj', 'of', 'ADP'), ('.', 'punct', 'captured', 'VERB')]
#
# As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India.
# [('As', 'mark', 'grew', 'VERB'), ('his', 'poss', 'conquests', 'NOUN'), ('conquests', 'nsubj', 'grew', 'VERB'), ('grew', 'advcl', 'formed', 'VERB'), (',', 'punct', 'formed', 'VERB'), ('he', 'nsubj', 'formed', 'VERB'), ('formed', 'ROOT', 'formed', 'VERB'), ('alliances', 'dobj', 'formed', 'VERB'), ('with', 'prep', 'alliances', 'NOUN'), ('local', 'amod', 'leaders', 'NOUN'), ('leaders', 'pobj', 'with', 'ADP'), (',', 'punct', 'alliances', 'NOUN'), ('securing', 'advcl', 'formed', 'VERB'), ('key', 'amod', 'forts', 'NOUN'), ('forts', 'dobj', 'securing', 'VERB'), ('like', 'prep', 'forts', 'NOUN'), ('Raigad', 'pobj', 'like', 'ADP'), (',', 'punct', 'Raigad', 'PROPN'), ('Kondana', 'conj', 'Raigad', 'PROPN'), (',', 'punct', 'Kondana', 'PROPN'), ('and', 'cc', 'Kondana', 'PROPN'), ('Purandar', 'conj', 'Kondana', 'PROPN'), (',', 'punct', 'securing', 'VERB'), ('establishing', 'conj', 'securing', 'VERB'), ('a', 'det', 'base', 'NOUN'), ('solid', 'amod', 'base', 'NOUN'), ('territorial', 'amod', 'base', 'NOUN'), ('base', 'dobj', 'establishing', 'VERB'), ('in', 'prep', 'base', 'NOUN'), ('western', 'amod', 'India', 'PROPN'), ('India', 'pobj', 'in', 'ADP'), ('.', 'punct', 'formed', 'VERB')]
#
# In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan.
# [('In', 'prep', 'faced', 'VERB'), ('1659', 'pobj', 'In', 'ADP'), (',', 'punct', 'faced', 'VERB'), ('he', 'nsubj', 'faced', 'VERB'), ('faced', 'ccomp', 'was', 'AUX'), ('and', 'cc', 'faced', 'VERB'), ('defeated', 'conj', 'faced', 'VERB'), ('Afzal', 'compound', 'Khan', 'PROPN'), ('Khan', 'dobj', 'defeated', 'VERB'), (',', 'punct', 'Khan', 'PROPN'), ('a', 'det', 'general', 'NOUN'), ('prominent', 'amod', 'general', 'NOUN'), ('general', 'appos', 'Khan', 'PROPN'), ('of', 'prep', 'general', 'NOUN'), ('the', 'det', 'Sultanate', 'PROPN'), ('Bijapur', 'compound', 'Sultanate', 'PROPN'), ('Sultanate', 'pobj', 'of', 'ADP'), (',', 'punct', 'Khan', 'PROPN'), ('solidifying', 'advcl', 'defeated', 'VERB'), ('his', 'poss', 'reputation', 'NOUN'), ('reputation', 'dobj', 'solidifying', 'VERB'), ('as', 'prep', 'reputation', 'NOUN'), ('a', 'det', 'leader', 'NOUN'), ('brave', 'amod', 'leader', 'NOUN'), ('and', 'cc', 'brave', 'ADJ'), ('tactical', 'conj', 'brave', 'ADJ'), ('leader', 'pobj', 'as', 'ADP'), (';', 'punct', 'was', 'AUX'), ('this', 'det', 'victory', 'NOUN'), ('victory', 'nsubj', 'was', 'AUX'), ('was', 'ROOT', 'was', 'AUX'), ('crucial', 'acomp', 'was', 'AUX'), ('in', 'prep', 'was', 'AUX'), ('establishing', 'pcomp', 'in', 'ADP'), ('his', 'poss', 'control', 'NOUN'), ('control', 'dobj', 'establishing', 'VERB'), ('over', 'prep', 'establishing', 'VERB'), ('much', 'pobj', 'over', 'ADP'), ('of', 'prep', 'much', 'ADJ'), ('the', 'det', 'Deccan', 'PROPN'), ('Deccan', 'pobj', 'of', 'ADP'), ('.', 'punct', 'was', 'AUX')]
#
# Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend.
# [('Shivaji', 'poss', 'raids', 'NOUN'), ('’s', 'case', 'Shivaji', 'PROPN'), ('raids', 'nsubj', 'bolstered', 'VERB'), ('on', 'prep', 'raids', 'NOUN'), ('Mughal', 'compound', 'territories', 'NOUN'), ('territories', 'pobj', 'on', 'ADP'), ('and', 'cc', 'territories', 'NOUN'), ('his', 'poss', 'escape', 'NOUN'), ('escape', 'conj', 'territories', 'NOUN'), ('from', 'prep', 'escape', 'NOUN'), ('the', 'det', 'clutches', 'NOUN'), ('clutches', 'pobj', 'from', 'ADP'), ('of', 'prep', 'clutches', 'NOUN'), ('Aurangzeb', 'pobj', 'of', 'ADP'), ('in', 'prep', 'clutches', 'NOUN'), ('Agra', 'pobj', 'in', 'ADP'), ('in', 'prep', 'raids', 'NOUN'), ('1666', 'pobj', 'in', 'ADP'), ('further', 'advmod', 'bolstered', 'VERB'), ('bolstered', 'ROOT', 'bolstered', 'VERB'), ('his', 'poss', 'legend', 'NOUN'), ('legend', 'dobj', 'bolstered', 'VERB'), ('.', 'punct', 'bolstered', 'VERB')]
#
# He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces.
# [('He', 'nsubj', 'realized', 'VERB'), ('realized', 'ROOT', 'realized', 'VERB'), ('that', 'mark', 'was', 'AUX'), ('a', 'det', 'navy', 'NOUN'), ('powerful', 'amod', 'navy', 'NOUN'), ('navy', 'nsubj', 'was', 'AUX'), ('was', 'ccomp', 'realized', 'VERB'), ('crucial', 'acomp', 'was', 'AUX'), ('to', 'aux', 'safeguard', 'VERB'), ('safeguard', 'xcomp', 'crucial', 'ADJ'), ('his', 'poss', 'territories', 'NOUN'), ('territories', 'dobj', 'safeguard', 'VERB'), ('from', 'prep', 'territories', 'NOUN'), ('foreign', 'amod', 'invasions', 'NOUN'), ('invasions', 'pobj', 'from', 'ADP'), (',', 'punct', 'was', 'AUX'), ('leading', 'advcl', 'realized', 'VERB'), ('him', 'dobj', 'leading', 'VERB'), ('to', 'aux', 'develop', 'VERB'), ('develop', 'xcomp', 'leading', 'VERB'), ('one', 'dobj', 'develop', 'VERB'), ('of', 'prep', 'one', 'NUM'), ('the', 'det', 'forces', 'NOUN'), ('earliest', 'amod', 'forces', 'NOUN'), ('organized', 'amod', 'forces', 'NOUN'), ('naval', 'amod', 'forces', 'NOUN'), ('forces', 'pobj', 'of', 'ADP'), ('in', 'prep', 'forces', 'NOUN'), ('India', 'pobj', 'in', 'ADP'), (',', 'punct', 'develop', 'VERB'), ('allowing', 'advcl', 'develop', 'VERB'), ('him', 'nsubj', 'secure', 'VERB'), ('to', 'aux', 'secure', 'VERB'), ('secure', 'ccomp', 'allowing', 'VERB'), ('coastal', 'amod', 'areas', 'NOUN'), ('areas', 'dobj', 'secure', 'VERB'), ('against', 'prep', 'areas', 'NOUN'), ('Portuguese', 'pobj', 'against', 'ADP'), (',', 'punct', 'Portuguese', 'ADJ'), ('British', 'conj', 'Portuguese', 'ADJ'), (',', 'punct', 'British', 'ADJ'), ('and', 'cc', 'British', 'ADJ'), ('Siddis', 'compound', 'forces', 'NOUN'), ('forces', 'conj', 'British', 'ADJ'), ('.', 'punct', 'realized', 'VERB')]
#
# In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos.
# [('In', 'prep', 'crowned', 'VERB'), ('1674', 'pobj', 'In', 'ADP'), (',', 'punct', 'crowned', 'VERB'), ('he', 'nsubj', 'crowned', 'VERB'), ('formally', 'advmod', 'crowned', 'VERB'), ('crowned', 'ROOT', 'crowned', 'VERB'), ('himself', 'dobj', 'crowned', 'VERB'), ('as', 'prep', 'crowned', 'VERB'), ('Chhatrapati', 'pobj', 'as', 'ADP'), ('at', 'prep', 'Chhatrapati', 'PROPN'), ('Raigad', 'compound', 'Fort', 'PROPN'), ('Fort', 'pobj', 'at', 'ADP'), (',', 'punct', 'crowned', 'VERB'), ('declaring', 'advcl', 'crowned', 'VERB'), ('his', 'poss', 'independence', 'NOUN'), ('independence', 'dobj', 'declaring', 'VERB'), ('and', 'cc', 'declaring', 'VERB'), ('establishing', 'conj', 'declaring', 'VERB'), ('the', 'det', 'Empire', 'PROPN'), ('Maratha', 'compound', 'Empire', 'PROPN'), ('Empire', 'dobj', 'establishing', 'VERB'), (',', 'punct', 'establishing', 'VERB'), ('thus', 'advmod', 'becoming', 'VERB'), ('becoming', 'advcl', 'establishing', 'VERB'), ('the', 'det', 'king', 'NOUN'), ('first', 'amod', 'king', 'NOUN'), ('king', 'attr', 'becoming', 'VERB'), ('to', 'aux', 'establish', 'VERB'), ('establish', 'relcl', 'king', 'NOUN'), ('Hindavi', 'compound', 'Swarajya', 'PROPN'), ('Swarajya', 'dobj', 'establish', 'VERB'), (',', 'punct', 'Swarajya', 'PROPN'), ('an', 'det', 'kingdom', 'NOUN'), ('autonomous', 'amod', 'kingdom', 'NOUN'), ('kingdom', 'appos', 'Swarajya', 'PROPN'), ('with', 'prep', 'kingdom', 'NOUN'), ('a', 'det', 'framework', 'NOUN'), ('structured', 'amod', 'framework', 'NOUN'), ('administrative', 'amod', 'framework', 'NOUN'), ('framework', 'pobj', 'with', 'ADP'), ('rooted', 'acl', 'framework', 'NOUN'), ('in', 'prep', 'rooted', 'VERB'), ('Indian', 'amod', 'ethos', 'NOUN'), ('ethos', 'pobj', 'in', 'ADP'), ('.', 'punct', 'crowned', 'VERB')]
#
# Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance.
# [('Shivaji', 'poss', 'system', 'NOUN'), ('’s', 'case', 'Shivaji', 'PROPN'), ('administrative', 'amod', 'system', 'NOUN'), ('system', 'nsubj', 'was', 'AUX'), ('was', 'ROOT', 'was', 'AUX'), ('highly', 'advmod', 'efficient', 'ADJ'), ('efficient', 'acomp', 'was', 'AUX'), (',', 'punct', 'was', 'AUX'), ('and', 'cc', 'was', 'AUX'), ('he', 'nsubj', 'emphasized', 'VERB'), ('emphasized', 'ccomp', 'included', 'VERB'), ('the', 'det', 'welfare', 'NOUN'), ('welfare', 'dobj', 'emphasized', 'VERB'), ('of', 'prep', 'welfare', 'NOUN'), ('his', 'poss', 'people', 'NOUN'), ('people', 'pobj', 'of', 'ADP'), (',', 'punct', 'emphasized', 'VERB'), ('setting', 'advcl', 'emphasized', 'VERB'), ('up', 'prt', 'setting', 'VERB'), ('systems', 'dobj', 'setting', 'VERB'), ('to', 'aux', 'reduce', 'VERB'), ('reduce', 'advcl', 'setting', 'VERB'), ('corruption', 'dobj', 'reduce', 'VERB'), ('and', 'cc', 'reduce', 'VERB'), ('create', 'conj', 'reduce', 'VERB'), ('a', 'det', 'structure', 'NOUN'), ('fair', 'amod', 'structure', 'NOUN'), ('tax', 'compound', 'structure', 'NOUN'), ('structure', 'dobj', 'create', 'VERB'), (';', 'punct', 'included', 'VERB'), ('his', 'poss', 'Pradhan', 'PROPN'), ('Ashta', 'compound', 'Pradhan', 'PROPN'), ('Pradhan', 'nsubj', 'included', 'VERB'), ('(', 'punct', 'Pradhan', 'PROPN'), ('Council', 'appos', 'Pradhan', 'PROPN'), ('of', 'prep', 'Council', 'PROPN'), ('Eight', 'nummod', 'Ministers', 'PROPN'), ('Ministers', 'pobj', 'of', 'ADP'), (')', 'punct', 'Pradhan', 'PROPN'), ('included', 'conj', 'was', 'AUX'), ('departments', 'dobj', 'included', 'VERB'), ('for', 'prep', 'departments', 'NOUN'), ('finance', 'pobj', 'for', 'ADP'), (',', 'punct', 'finance', 'NOUN'), ('internal', 'amod', 'affairs', 'NOUN'), ('affairs', 'conj', 'finance', 'NOUN'), (',', 'punct', 'affairs', 'NOUN'), ('foreign', 'amod', 'policy', 'NOUN'), ('policy', 'conj', 'affairs', 'NOUN'), (',', 'punct', 'policy', 'NOUN'), ('and', 'cc', 'policy', 'NOUN'), ('military', 'conj', 'policy', 'NOUN'), ('to', 'aux', 'ensure', 'VERB'), ('ensure', 'advcl', 'military', 'NOUN'), ('smooth', 'amod', 'governance', 'NOUN'), ('governance', 'dobj', 'ensure', 'VERB'), ('.', 'punct', 'included', 'VERB')]
#
# Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.
# [('Shivaji', 'nsubj', 'showed', 'VERB'), ('showed', 'ROOT', 'showed', 'VERB'), ('a', 'det', 'approach', 'NOUN'), ('progressive', 'amod', 'approach', 'NOUN'), ('approach', 'dobj', 'showed', 'VERB'), ('towards', 'prep', 'approach', 'NOUN'), ('governance', 'pobj', 'towards', 'ADP'), (',', 'punct', 'showed', 'VERB'), ('promoting', 'advcl', 'showed', 'VERB'), ('religious', 'amod', 'tolerance', 'NOUN'), ('tolerance', 'dobj', 'promoting', 'VERB'), ('and', 'cc', 'promoting', 'VERB'), ('respecting', 'conj', 'promoting', 'VERB'), ('the', 'det', 'diversity', 'NOUN'), ('diversity', 'dobj', 'respecting', 'VERB'), ('within', 'prep', 'diversity', 'NOUN'), ('his', 'poss', 'empire', 'NOUN'), ('empire', 'pobj', 'within', 'ADP'), (',', 'punct', 'promoting', 'VERB'), ('even', 'advmod', 'appointing', 'VERB'), ('appointing', 'conj', 'promoting', 'VERB'), ('Muslims', 'dobj', 'appointing', 'VERB'), ('to', 'prep', 'appointing', 'VERB'), ('key', 'amod', 'positions', 'NOUN'), ('positions', 'pobj', 'to', 'ADP'), ('in', 'prep', 'positions', 'NOUN'), ('his', 'poss', 'administration', 'NOUN'), ('administration', 'pobj', 'in', 'ADP'), ('and', 'cc', 'appointing', 'VERB'), ('banning', 'conj', 'appointing', 'VERB'), ('the', 'det', 'harassment', 'NOUN'), ('harassment', 'dobj', 'banning', 'VERB'), ('of', 'prep', 'harassment', 'NOUN'), ('women', 'pobj', 'of', 'ADP'), ('and', 'cc', 'women', 'NOUN'), ('looting', 'conj', 'women', 'NOUN'), ('of', 'prep', 'looting', 'NOUN'), ('religious', 'amod', 'sites', 'NOUN'), ('sites', 'pobj', 'of', 'ADP'), ('.', 'punct', 'showed', 'VERB')]
#
# His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time.
# [('His', 'poss', 'respect', 'NOUN'), ('respect', 'nsubj', 'inspired', 'VERB'), ('for', 'prep', 'respect', 'NOUN'), ('women', 'pobj', 'for', 'ADP'), ('and', 'cc', 'women', 'NOUN'), ('his', 'poss', 'advocacy', 'NOUN'), ('advocacy', 'conj', 'women', 'NOUN'), ('for', 'prep', 'advocacy', 'NOUN'), ('justice', 'pobj', 'for', 'ADP'), ('inspired', 'ROOT', 'inspired', 'VERB'), ('trust', 'dobj', 'inspired', 'VERB'), ('and', 'cc', 'trust', 'NOUN'), ('loyalty', 'conj', 'trust', 'NOUN'), ('among', 'prep', 'inspired', 'VERB'), ('his', 'poss', 'people', 'NOUN'), ('people', 'pobj', 'among', 'ADP'), (',', 'punct', 'inspired', 'VERB'), ('making', 'advcl', 'inspired', 'VERB'), ('him', 'nsubj', 'ruler', 'NOUN'), ('an', 'det', 'ruler', 'NOUN'), ('ideal', 'amod', 'ruler', 'NOUN'), ('ruler', 'ccomp', 'making', 'VERB'), ('for', 'prep', 'ruler', 'NOUN'), ('his', 'poss', 'time', 'NOUN'), ('time', 'pobj', 'for', 'ADP'), ('.', 'punct', 'inspired', 'VERB')]
#
# Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses.
# [('Shivaji', 'compound', 'Maharaj', 'PROPN'), ('Maharaj', 'poss', 'tactics', 'NOUN'), ('’s', 'case', 'Maharaj', 'PROPN'), ('guerrilla', 'compound', 'tactics', 'NOUN'), ('tactics', 'nsubj', 'became', 'VERB'), (',', 'punct', 'tactics', 'NOUN'), ('known', 'acl', 'tactics', 'NOUN'), ('as', 'prep', 'known', 'VERB'), ('“', 'punct', 'as', 'ADP'), ('Ganimi', 'compound', 'Kava', 'PROPN'), ('Kava', 'pobj', 'as', 'ADP'), (',', 'punct', 'tactics', 'NOUN'), ('”', 'punct', 'tactics', 'NOUN'), ('became', 'ROOT', 'became', 'VERB'), ('legendary', 'acomp', 'became', 'VERB'), ('and', 'cc', 'became', 'VERB'), ('enabled', 'conj', 'became', 'VERB'), ('him', 'dobj', 'enabled', 'VERB'), ('to', 'aux', 'outmaneuver', 'VERB'), ('outmaneuver', 'xcomp', 'enabled', 'VERB'), ('much', 'advmod', 'larger', 'ADJ'), ('larger', 'amod', 'armies', 'NOUN'), ('and', 'cc', 'larger', 'ADJ'), ('better', 'advmod', 'equipped', 'VERB'), ('-', 'punct', 'equipped', 'VERB'), ('equipped', 'conj', 'larger', 'ADJ'), ('armies', 'dobj', 'outmaneuver', 'VERB'), ('repeatedly', 'advmod', 'outmaneuver', 'VERB'), (',', 'punct', 'outmaneuver', 'VERB'), ('allowing', 'advcl', 'outmaneuver', 'VERB'), ('him', 'nsubj', 'expand', 'VERB'), ('to', 'aux', 'expand', 'VERB'), ('expand', 'ccomp', 'allowing', 'VERB'), ('his', 'poss', 'empire', 'NOUN'), ('empire', 'dobj', 'expand', 'VERB'), ('while', 'mark', 'minimizing', 'VERB'), ('minimizing', 'advcl', 'expand', 'VERB'), ('losses', 'dobj', 'minimizing', 'VERB'), ('.', 'punct', 'became', 'VERB')]
#
# As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India.
# [('As', 'mark', 'grew', 'VERB'), ('his', 'poss', 'fame', 'NOUN'), ('fame', 'nsubj', 'grew', 'VERB'), ('grew', 'advcl', 'began', 'VERB'), (',', 'punct', 'began', 'VERB'), ('the', 'det', 'Empire', 'PROPN'), ('Maratha', 'compound', 'Empire', 'PROPN'), ('Empire', 'nsubj', 'began', 'VERB'), ('began', 'ROOT', 'began', 'VERB'), ('to', 'aux', 'influence', 'VERB'), ('influence', 'xcomp', 'began', 'VERB'), ('regions', 'dobj', 'influence', 'VERB'), ('far', 'advmod', 'beyond', 'ADP'), ('beyond', 'prep', 'influence', 'VERB'), ('Maharashtra', 'pobj', 'beyond', 'ADP'), (',', 'punct', 'influence', 'VERB'), ('with', 'prep', 'influence', 'VERB'), ('Maratha', 'compound', 'forces', 'NOUN'), ('forces', 'nsubj', 'becoming', 'VERB'), ('eventually', 'advmod', 'becoming', 'VERB'), ('becoming', 'pcomp', 'with', 'ADP'), ('a', 'det', 'power', 'NOUN'), ('significant', 'amod', 'power', 'NOUN'), ('power', 'attr', 'becoming', 'VERB'), ('across', 'prep', 'power', 'NOUN'), ('India', 'pobj', 'across', 'ADP'), ('.', 'punct', 'began', 'VERB')]
#
# Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.
# [('Shivaji', 'nsubj', 'passed', 'VERB'), ('passed', 'ROOT', 'passed', 'VERB'), ('away', 'prt', 'passed', 'VERB'), ('on', 'prep', 'passed', 'VERB'), ('April', 'pobj', 'on', 'ADP'), ('3', 'nummod', 'April', 'PROPN'), (',', 'punct', 'April', 'PROPN'), ('1680', 'nummod', 'April', 'PROPN'), (',', 'punct', 'April', 'PROPN'), ('at', 'prep', 'passed', 'VERB'), ('Raigad', 'compound', 'Fort', 'PROPN'), ('Fort', 'pobj', 'at', 'ADP'), (',', 'punct', 'passed', 'VERB'), ('leaving', 'advcl', 'passed', 'VERB'), ('behind', 'prt', 'leaving', 'VERB'), ('a', 'det', 'legacy', 'NOUN'), ('powerful', 'amod', 'legacy', 'NOUN'), ('legacy', 'dobj', 'leaving', 'VERB'), ('and', 'cc', 'legacy', 'NOUN'), ('a', 'det', 'state', 'NOUN'), ('well', 'advmod', 'organized', 'VERB'), ('-', 'punct', 'organized', 'VERB'), ('organized', 'amod', 'state', 'NOUN'), ('state', 'conj', 'legacy', 'NOUN'), ('that', 'nsubj', 'continued', 'VERB'), ('continued', 'relcl', 'state', 'NOUN'), ('to', 'aux', 'expand', 'VERB'), ('expand', 'xcomp', 'continued', 'VERB'), ('after', 'prep', 'expand', 'VERB'), ('his', 'poss', 'death', 'NOUN'), ('death', 'pobj', 'after', 'ADP'), ('.', 'punct', 'passed', 'VERB')]
#
# His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.
# [('His', 'poss', 'life', 'NOUN'), ('life', 'nsubj', 'continue', 'VERB'), ('and', 'cc', 'life', 'NOUN'), ('ideals', 'conj', 'life', 'NOUN'), ('—', 'punct', 'life', 'NOUN'), ('valor', 'appos', 'life', 'NOUN'), (',', 'punct', 'valor', 'NOUN'), ('respect', 'appos', 'life', 'NOUN'), ('for', 'prep', 'respect', 'NOUN'), ('all', 'det', 'faiths', 'NOUN'), ('faiths', 'pobj', 'for', 'ADP'), (',', 'punct', 'respect', 'NOUN'), ('and', 'cc', 'respect', 'NOUN'), ('self', 'compound', 'rule', 'NOUN'), ('-', 'punct', 'rule', 'NOUN'), ('rule', 'conj', 'respect', 'NOUN'), ('—', 'punct', 'life', 'NOUN'), ('continue', 'ROOT', 'continue', 'VERB'), ('to', 'aux', 'inspire', 'VERB'), ('inspire', 'xcomp', 'continue', 'VERB'), ('millions', 'dobj', 'inspire', 'VERB'), (',', 'punct', 'continue', 'VERB'), ('and', 'cc', 'continue', 'VERB'), ('his', 'poss', 'legacy', 'NOUN'), ('legacy', 'nsubj', 'endures', 'VERB'), ('endures', 'conj', 'continue', 'VERB'), ('in', 'prep', 'endures', 'VERB'), ('the', 'det', 'form', 'NOUN'), ('form', 'pobj', 'in', 'ADP'), ('of', 'prep', 'form', 'NOUN'), ('the', 'det', 'Empire', 'PROPN'), ('Maratha', 'compound', 'Empire', 'PROPN'), ('Empire', 'poss', 'contributions', 'NOUN'), ('’s', 'case', 'Empire', 'PROPN'), ('contributions', 'pobj', 'of', 'ADP'), ('to', 'prep', 'contributions', 'NOUN'), ('India', 'poss', 'history', 'NOUN'), ('’s', 'case', 'India', 'PROPN'), ('history', 'pobj', 'to', 'ADP'), ('and', 'cc', 'history', 'NOUN'), ('culture', 'conj', 'history', 'NOUN'), ('.', 'punct', 'endures', 'VERB')]

# %%
# Visualizing the dependency tree of the first sentence using spaCy’s displacy tool.

from spacy import displacy

displacy.render(doc, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="635689b1cb514d2ca1296bd2fca36d57-0" class="displacy" width="91575" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Chhatrapati</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Shivaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Maharaj</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">February</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">19,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">1630,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Shivneri</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Fort</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Maharashtra,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Shahaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Bhonsle,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Maratha</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">general,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Jijabai,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">deeply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">influenced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Shivaji</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">teachings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">dharma,</tspan>
#     <tspan class="displa

# %% [markdown]
#  # 10- Phrase Matching

# %%
# Identify occurrences of the phrase "Maratha Empire" using spaCy's PhraseMatcher.

from spacy.matcher import PhraseMatcher

nlp = spacy.load('en_core_web_sm')
text = test

matcher = PhraseMatcher(nlp.vocab)
pattern = nlp("Maratha Empire")
matcher.add("MARATHA_EMPIRE", None, pattern)

doc = nlp(text)
matches = matcher(doc)

for match_id, start, end in matches:
    print(f"found at index: {start} - {end}, Phrase: '{doc[start:end]}'") {start}-{end}")
# Out:
#   Cell In[68], line 16
#     print(f"found at index: {start} - {end}, Phrase: '{doc[start:end]}'") {start}-{end}")
#                                                                                        ^
# SyntaxError: unterminated string literal (detected at line 16)

# %% [markdown]
# # 11- Sentence Similarity

# %%
#Calculate the similarity between the first two sentences of the text using spaCy.
# Calculate the similarity between the first two sentences
# Extract the first two sentences
sentences = list(doc.sents)
first_sentence = sentences[0]
second_sentence = sentences[1]

# Calculate the similarity between the two sentences
similarity = first_sentence.similarity(second_sentence)

# Display the similarity score
print(f"Similarity between the first two sentences: {similarity:.4f}")
# Out:
# Similarity between the first two sentences: 0.3347
# C:\Users\HP\AppData\Local\Temp\ipykernel_20956\2908866518.py:9: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Span.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = first_sentence.similarity(second_sentence)

# %%
#Use TextBlob to compute the similarity between sentences mentioning "Shivaji" and "Mughal Empire."
# Extract sentences
sentences = blob.sentences

# Initialize variables to hold the sentences
shivaji_sentence = None
mughal_sentence = None

# Find sentences mentioning "Shivaji" and "Mughal Empire"
for sentence in sentences:
    if "Shivaji" in sentence.raw:
        shivaji_sentence = sentence
    if "Mughal Empire" in sentence.raw:
        mughal_sentence = sentence

# Calculate similarity using spaCy if both sentences are found
if shivaji_sentence and mughal_sentence:
    # Convert TextBlob sentences to spaCy Docs
     doc1 = nlp(shivaji_sentence.raw)
     doc2 = nlp(mughal_sentence.raw)
    # Calculate similarity using spaCy's similarity method
     similarity = doc1.similarity(doc2)
     print(f"Similarity between sentences mentioning 'Shivaji' and 'Mughal Empire': {similarity:.4f}")
else:
    print("One or both sentences not found.")
# Out:
# Similarity between sentences mentioning 'Shivaji' and 'Mughal Empire': 0.6801
# C:\Users\HP\AppData\Local\Temp\ipykernel_20956\768076264.py:22: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = doc1.similarity(doc2)

# %% [markdown]
# # 12- Translation

# %%
# !pip install deep-translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in c:\users\hp\anaconda3\lib\site-packages (from deep-translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\hp\anaconda3\lib\site-packages (from deep-translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2024.8.30)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ---------------------------------------- 0.0/42.3 kB ? eta -:--:--
#    ---------------------------------------- 42.3/42.3 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4

# %%
#Translate the first paragraph into Hindi using TextBlob.
from deep_translator import GoogleTranslator

# Translate the text into Hindi
translated_text = GoogleTranslator(source='en', target='hi').translate(text)

# Print the translated text
translated_text
# Out:
# 'छत्रपति शिवाजी महाराज का जन्म 19 फरवरी, 1630 को महाराष्ट्र के शिवनेरी किले में, मराठा सेनापति शाहजी भोंसले और जीजाबाई के घर हुआ था, जिन्होंने धर्म, बहादुरी और न्याय की अपनी शिक्षाओं से शिवाजी को गहराई से प्रभावित किया था। कम उम्र से ही, शिवाजी ने उल्लेखनीय नेतृत्व गुणों का प्रदर्शन किया, वफादार अनुयायियों का एक समूह बनाया और सह्याद्री पहाड़ों के बीहड़ इलाकों में अपने सैन्य कौशल को बढ़ाया। वह ऐसे समय में बड़ा हुआ जब सम्राट औरंगजेब और दक्कन सल्तनत के अधीन मुगल साम्राज्य नियंत्रण के लिए होड़ कर रहा था, अक्सर स्थानीय आबादी पर अत्याचार करता था, जिसने उसे बहुत परेशान किया और मराठों के लिए स्वराज्य, या स्व-शासन स्थापित करने की उसकी इच्छा को बढ़ावा दिया। 16 साल की उम्र तक, शिवाजी ने गुरिल्ला युद्ध रणनीति का उपयोग करके अपने पहले किले, तोरण पर कब्जा कर लिया था जैसे-जैसे उनकी विजय बढ़ती गई, उन्होंने स्थानीय नेताओं के साथ गठबंधन किया, रायगढ़, कोंडाना और पुरंदर जैसे प्रमुख किलों को सुरक्षित किया, पश्चिमी भारत में एक ठोस क्षेत्रीय आधार स्थापित किया। 1659 में, उन्होंने बीजापुर सल्तनत के एक प्रमुख सेनापति अफ़ज़ल खान का सामना किया और उसे हराया, जिससे एक बहादुर और सामरिक नेता के रूप में उनकी प्रतिष्ठा मजबूत हुई; यह जीत डेक्कन के अधिकांश हिस्से पर अपना नियंत्रण स्थापित करने में महत्वपूर्ण थी। मुगल क्षेत्रों पर शिवाजी के छापे और 1666 में आगरा में औरंगज़ेब के चंगुल से उनके भागने ने उनकी किंवदंती को और मजबूत किया। उन्होंने महसूस किया कि विदेशी आक्रमणों से अपने क्षेत्रों की रक्षा के लिए एक शक्तिशाली नौसेना महत्वपूर्ण थी, जिसके कारण उन्होंने भारत में सबसे शुरुआती संगठित नौसेना बलों में से एक विकसित किया, जिससे उन्हें पुर्तगाली, ब्रिटिश और सिद्दी सेनाओं के खिलाफ तटीय क्षेत्रों को सुरक्षित करने में मदद मिली। 1674 में, उन्होंने औपचारिक रूप से रायगढ़ किले में छत्रपति के रूप में खुद को ताज पहनाया, अपनी स्वतंत्रता की घोषणा की और मराठा साम्राज्य की स्थापना की, इस प्रकार वे हिंदवी स्वराज्य की स्थापना करने वाले पहले राजा बन गए, जो भारतीय लोकाचार में निहित एक संरचित प्रशासनिक ढांचे वाला एक स्वायत्त राज्य था। शिवाजी की प्रशासनिक व्यवस्था अत्यधिक कुशल थी, और उन्होंने अपने लोगों के कल्याण पर जोर दिया, भ्रष्टाचार को कम करने और एक निष्पक्ष कर संरचना बनाने के लिए सिस्टम स्थापित किए; उनके अष्ट प्रधान (आठ मंत्रियों की परिषद) में सुचारू शासन सुनिश्चित करने के लिए वित्त, आंतरिक मामले, विदेश नीति और सैन्य विभाग शामिल थे। शिवाजी ने शासन के प्रति एक प्रगतिशील दृष्टिकोण दिखाया, धार्मिक सहिष्णुता को बढ़ावा दिया और अपने साम्राज्य के भीतर विविधता का सम्मान किया, यहाँ तक कि मुसलमानों को अपने प्रशासन में प्रमुख पदों पर नियुक्त किया और महिलाओं के उत्पीड़न और धार्मिक स्थलों की लूट पर प्रतिबंध लगा दिया। महिलाओं के प्रति उनके सम्मान और न्याय के लिए उनकी वकालत ने उनके लोगों के बीच विश्वास और वफादारी को प्रेरित किया, जिससे वे अपने समय के लिए एक आदर्श शासक बन गए। शिवाजी महाराज की गुरिल्ला रणनीति, जिसे "गनीमी कावा" के रूप में जाना जाता है, प्रसिद्ध हो गई और उन्हें बार-बार बहुत बड़ी और बेहतर सुसज्जित सेनाओं को मात देने में सक्षम बनाया, जिससे उन्हें नुकसान को कम करते हुए अपने साम्राज्य का विस्तार करने में मदद मिली। जैसे-जैसे उनकी प्रसिद्धि बढ़ी, मराठा साम्राज्य ने महाराष्ट्र से परे क्षेत्रों को प्रभावित करना शुरू कर दिया, और मराठा सेना अंततः पूरे भारत में एक महत्वपूर्ण शक्ति बन गई। शिवाजी का निधन 3 अप्रैल, 1680 को रायगढ़ किले में हुआ था, वे अपने पीछे एक शक्तिशाली विरासत और एक सुव्यवस्थित राज्य छोड़ गए थे जो उनकी मृत्यु के बाद भी बढ़ता रहा। उनका जीवन और आदर्श - वीरता, सभी धर्मों के प्रति सम्मान और स्वशासन - लाखों लोगों को प्रेरित करते हैं, और उनकी विरासत भारत के इतिहास और संस्कृति में मराठा साम्राज्य के योगदान के रूप में कायम है।'

# %%
#Translate the phrase "Hindavi Swarajya" into French using TextBlob
# Translate the phrase into French
# Phrase to translate
phrase = "Hindavi Swarajya"

# Create a TextBlob object
blob1 = TextBlob(phrase)

translated_french = GoogleTranslator(source='auto', target='fr').translate(phrase)

# Translate the phrase into French
try:
    translated_blob = blob1.translate(to='fr')
    # Print the translated text
    print(translated_blob)
except Exception as e:
    print(translated_french)
# Out:
# Hindavi Swarajya

# %% [markdown]
#  # 13- Keyword Extraction

# %%
#Extract keywords using NLTK’s frequency distribution (common nouns and verbs).
# Tokenize the text into words
words = word_tokenize(text)

# Perform part-of-speech tagging
tagged_words = pos_tag(words)

# Filter for common nouns (NN, NNS) and verbs (VB, VBD, VBG, VBN, VBP, VBZ)
nouns_and_verbs = [word for word, pos in tagged_words if pos.startswith('NN') or pos.startswith('VB')]

# Compute frequency distribution
freq_dist = FreqDist(nouns_and_verbs)

# Get the most common nouns and verbs
common_keywords = freq_dist.most_common(10)

# Print the common keywords
print("Common nouns and verbs:")
for word, frequency in common_keywords:
    print(f"{word}: {frequency}")
# Out:
# Common nouns and verbs:
# Shivaji: 9
# Maratha: 5
# ’: 5
# was: 4
# Empire: 4
# India: 4
# Fort: 3
# grew: 3
# Raigad: 3
# establishing: 3

# %%
#Use spaCy to identify and list unique keywords from the text (filter out stop words).

# Extract unique keywords (nouns and verbs), filtering out stop words and punctuation
unique_keywords = set()

for token in doc:
    if not token.is_stop and not token.is_punct and (token.pos_ in ['NOUN', 'VERB']):
        unique_keywords.add(token.lemma_)  # Use the lemma for base forms of words

# Convert the set to a sorted list for easier viewing
unique_keywords_list = sorted(unique_keywords)

# Print the unique keywords
print("Unique keywords (nouns and verbs):")
for keyword in unique_keywords_list:
    print(keyword)
# Out:
# Unique keywords (nouns and verbs):
# administration
# advocacy
# affair
# age
# alliance
# allow
# appoint
# approach
# area
# army
# ban
# base
# bear
# begin
# bolster
# bravery
# capture
# clutch
# conquest
# continue
# contribution
# control
# corruption
# create
# crown
# culture
# death
# declare
# defeat
# department
# desire
# develop
# dharma
# disturb
# diversity
# emphasize
# empire
# enable
# endure
# ensure
# equip
# escape
# establish
# ethos
# exhibit
# expand
# face
# faith
# fame
# finance
# follower
# force
# form
# fort
# framework
# fuel
# general
# governance
# group
# grow
# guerrilla
# hallmark
# harassment
# history
# hone
# ideal
# include
# independence
# influence
# inspire
# invasion
# justice
# king
# kingdom
# know
# lead
# leader
# leadership
# leave
# legacy
# legend
# life
# looting
# loss
# loyalty
# make
# military
# million
# minimize
# mountain
# navy
# oppress
# organize
# outmaneuver
# pass
# people
# policy
# population
# position
# power
# promote
# quality
# raid
# realize
# reduce
# region
# reputation
# respect
# root
# rule
# ruler
# safeguard
# secure
# self
# set
# show
# site
# skill
# solidify
# state
# strategy
# structure
# system
# tactic
# tax
# teaching
# terrain
# territory
# time
# tolerance
# trust
# valor
# victory
# vie
# warfare
# welfare
# woman

# %% [markdown]
#  # 14- Coreference Resolution

# %%
# !pip install git+https://github.com/huggingface/neuralcoref.git
# Out:
# Collecting git+https://github.com/huggingface/neuralcoref.git
#   Cloning https://github.com/huggingface/neuralcoref.git to c:\users\hp\appdata\local\temp\pip-req-build-_adyl9_s
#   Resolved https://github.com/huggingface/neuralcoref.git to commit 60338df6f9b0a44a6728b442193b7c66653b0731
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/neuralcoref.git 'C:\Users\HP\AppData\Local\Temp\pip-req-build-_adyl9_s'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [6 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\HP\AppData\Local\Temp\pip-req-build-_adyl9_s\setup.py", line 44, in <module>
#       from distutils import ccompiler, msvccompiler
#   ImportError: cannot import name 'msvccompiler' from 'distutils' (C:\Users\HP\anaconda3\Lib\site-packages\setuptools\_distutils\__init__.py). Did you mean: 'ccompiler'?
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
#Identify any instances where pronouns can be replaced with entity names for better clarity.

# Prepare a mapping of pronouns to their referents
pronoun_to_entity = {}

# Identify named entities and their text
entities = {ent.text: ent for ent in doc.ents}

# Loop through tokens to find pronouns and map them to entities
for token in doc:
    if token.pos_ == "PRON":
        # Look for the preceding noun that is a named entity
         if token.dep_ == "nsubj" and any(token.head.i in range(ent.start, ent.end) for ent in doc.ents):
            # Find the entity that the head is part of
            for ent in doc.ents:
                if token.head.i in range(ent.start, ent.end):
                    pronoun_to_entity[token.text] = ent.text
                    break

# Print the mapping of pronouns to entities
print("Pronouns and their referents:")
for pronoun, entity in pronoun_to_entity.items():
    print(f"{pronoun} -> {entity}")

# Replace pronouns with corresponding entities in the text for better clarity
resolved_text = text
for pronoun, entity in pronoun_to_entity.items():
    resolved_text = resolved_text.replace(pronoun, entity)

print("\nResolved Text for Clarity:")
print(resolved_text)
# Out:
# Pronouns and their referents:
#
# Resolved Text for Clarity:
# Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings on dharma, bravery, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains. He grew up during a time when the Mughal Empire under Emperor Aurangzeb and the Deccan Sultanates were vying for control, often oppressing the local population, which deeply disturbed him and fueled his desire to establish Swarajya, or self-rule for the Marathas. By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy. As his conquests grew, he formed alliances with local leaders, securing key forts like Raigad, Kondana, and Purandar, establishing a solid territorial base in western India. In 1659, he faced and defeated Afzal Khan, a prominent general of the Bijapur Sultanate, solidifying his reputation as a brave and tactical leader; this victory was crucial in establishing his control over much of the Deccan. Shivaji’s raids on Mughal territories and his escape from the clutches of Aurangzeb in Agra in 1666 further bolstered his legend. He realized that a powerful navy was crucial to safeguard his territories from foreign invasions, leading him to develop one of the earliest organized naval forces in India, allowing him to secure coastal areas against Portuguese, British, and Siddis forces. In 1674, he formally crowned himself as Chhatrapati at Raigad Fort, declaring his independence and establishing the Maratha Empire, thus becoming the first king to establish Hindavi Swarajya, an autonomous kingdom with a structured administrative framework rooted in Indian ethos. Shivaji’s administrative system was highly efficient, and he emphasized the welfare of his people, setting up systems to reduce corruption and create a fair tax structure; his Ashta Pradhan (Council of Eight Ministers) included departments for finance, internal affairs, foreign policy, and military to ensure smooth governance. Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites. His respect for women and his advocacy for justice inspired trust and loyalty among his people, making him an ideal ruler for his time. Shivaji Maharaj’s guerrilla tactics, known as “Ganimi Kava,” became legendary and enabled him to outmaneuver much larger and better-equipped armies repeatedly, allowing him to expand his empire while minimizing losses. As his fame grew, the Maratha Empire began to influence regions far beyond Maharashtra, with Maratha forces eventually becoming a significant power across India. Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death. His life and ideals—valor, respect for all faiths, and self-rule—continue to inspire millions, and his legacy endures in the form of the Maratha Empire’s contributions to India’s history and culture.

# %% [markdown]
#  # 15- Sentiment Polarity Distribution

# %%
#Calculate and plot the sentiment polarity distribution for each sentence in the text using TextBlob.
import matplotlib.pyplot as plt

# Process the text and split into sentences
sentences = [sent.text for sent in doc.sents]

# Calculate sentiment polarity for each sentence
polarities = [TextBlob(sentence).sentiment.polarity for sentence in sentences]

#Plotting the sentiment polarity distribution as a line plot
plt.figure(figsize=(10, 6))
plt.plot(range(len(sentences)), polarities, marker='o', linestyle='-', color='skyblue')
plt.xticks(range(len(sentences)), [f"Sentence {i+1}" for i in range(len(sentences))], rotation=90, fontsize=10)
plt.xlabel('Sentences')
plt.ylabel('Sentiment Polarity')
plt.title('Sentiment Polarity Distribution of Each Sentence')
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')  # Line at polarity = 0
plt.ylim(-1, 1)  # Limit the y-axis for better visibility
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
#  # 17- Synonyms and Antonyms

# %%
#Use TextBlob's WordNet to find synonyms for "bravery," "justice," and "valor."
from textblob import Word
# Words to find synonyms for
words = ["bravery", "justice", "valor"]

# Function to find synonyms
def find_synonyms(word):
    synonyms = set()  # Use a set to avoid duplicate synonyms
    for syn in Word(word).synsets:
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())  # Add synonym to the set
    return synonyms

# Find and display synonyms for each word
for word in words:
    synonyms = find_synonyms(word)
    print(f"Synonyms for '{word}': {', '.join(synonyms)}")
# Out:
# Synonyms for 'bravery': courageousness, fearlessness, braveness, courage, bravery
# Synonyms for 'justice': DoJ, Justice_Department, jurist, Department_of_Justice, judge, justice, Justice, justness
# Synonyms for 'valor': valiancy, gallantry, valour, heroism, valorousness, valiance, valor

# %% [markdown]
# # 18- Spelling Correction

# %%
#Introduce 5 spelling errors in the text and use TextBlob to correct them.
text_with_errors = """
Chhatrapati Shivaji Maharaj was born on Febuary 19, 1630, at Shivneri Fort in Maharashtra, to Shahaji Bhonsle, a Maratha genral, and Jijabai, who deeply influanced Shivaji with her teachings on dharma, braveness, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountans.
"""

# Create a TextBlob object with the text containing errors
blob2 = TextBlob(text_with_errors)
# Correct the spelling errors
corrected_text = blob2.correct()
# Display the corrected text
print("Corrected Text:")
print(corrected_text)
# Out:
# Corrected Text:
#
# Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Sort in Maharashtra, to Shahaji Bhonsle, a Martha general, and Jijabai, who deeply influenced Shivaji with her teachings on harm, baseness, and justice. From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and hoping his military skill in the rugged terrain of the Sahyadri mountains.

# %% [markdown]
#  # 19- Extract Subject-Verb-Object Triples

# %%
#Use spaCy to extract subject-verb-object triples from the sentences.
# Function to extract SVO triples
def extract_svo(doc):
    svos = []
    for sent in doc.sents:
        subject = ''
        verb = ''
        obj = ''

        # Iterate through tokens in the sentence
        for token in sent:
            # Identify the subject
            if 'subj' in token.dep_:
                subject = token.text

            # Identify the verb
            if token.dep_ == 'ROOT':
                verb = token.text

            # Identify the object
            if 'obj' in token.dep_:
                obj = token.text

        # Append the SVO tuple if all three components are found
        if subject and verb and obj:
            svos.append((subject, verb, obj))

    return svos

# Extract and display SVO triples
svo_triples = extract_svo(doc)
print("Subject-Verb-Object Triples:")
for svo in svo_triples:
    print(svo)
# Out:
# Subject-Verb-Object Triples:
# ('who', 'born', 'dharma')
# ('Shivaji', 'exhibited', 'mountains')
# ('which', 'grew', 'Marathas')
# ('that', 'captured', 'strategy')
# ('he', 'formed', 'India')
# ('victory', 'was', 'Deccan')
# ('raids', 'bolstered', 'legend')
# ('him', 'realized', 'Portuguese')
# ('he', 'crowned', 'ethos')
# ('Pradhan', 'was', 'governance')
# ('Shivaji', 'showed', 'sites')
# ('him', 'inspired', 'time')
# ('him', 'became', 'losses')
# ('forces', 'began', 'India')
# ('that', 'passed', 'death')
# ('legacy', 'continue', 'history')

# %%
#identify and list sentences where "Shivaji" is the subject and a verb follows, using dependency parsing.
# Function to identify sentences with "
def find_sentences_with_shivaji(doc):
    sentences_with_shivaji = []
    for sent in doc.sents:
        shivaji_found = False
        verb_found = False

        # Iterate through tokens in the sentence
        for token in sent:
            # Check if "Shivaji" is the subject
            if 'subj' in token.dep_ and token.text == 'Shivaji':
                shivaji_found = True

            # Check if a verb follows "Shivaji"
            if shivaji_found and token.pos_ == 'VERB':
                verb_found = True
                break

        # Append the sentence if both "Shivaji" and a verb are found
        if shivaji_found and verb_found:
            sentences_with_shivaji.append(sent.text)

    return sentences_with_shivaji

# Find sentences with "Shivaji" and a verb
sentences_with_shivaji = find_sentences_with_shivaji(doc)
print("Sentences with 'Shivaji' and a verb:")
for sentence in sentences_with_shivaji:
    print(sentence)
# Out:
# Sentences with 'Shivaji' and a verb:
# From an early age, Shivaji exhibited remarkable leadership qualities, forming a group of loyal followers and honing his military skills in the rugged terrain of the Sahyadri mountains.
# By the age of 16, Shivaji had captured his first fort, Torna, using guerrilla warfare tactics that would later become a hallmark of his military strategy.
# Shivaji showed a progressive approach towards governance, promoting religious tolerance and respecting the diversity within his empire, even appointing Muslims to key positions in his administration and banning the harassment of women and looting of religious sites.
# Shivaji passed away on April 3, 1680, at Raigad Fort, leaving behind a powerful legacy and a well-organized state that continued to expand after his death.

# %% [markdown]
#  # 20- Create a Summary

# %%
from textblob import TextBlob
from collections import Counter

# Define the text to be summarized
text = "Your text goes here."

# Create a TextBlob object
blob = TextBlob(text)

# Calculate word frequencies
word_frequencies = Counter(blob.words)

# Score sentences based on the sum of word frequencies
sentence_scores = {}
for sentence in blob.sentences:
    sentence_scores[sentence] = sum(word_frequencies[word] for word in sentence.words)

# Sort sentences based on their score and select the top 5 sentences
summary_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)[:5]

# Display the summarized text
print("Summary:")
for sentence in summary_sentences:
    print(sentence)
# Out:
# Summary:
# Your text goes here.

# %%
from textblob import TextBlob
from collections import Counter

# Define the text to be summarized
text = """Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra, 
to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings 
on dharma, bravery, and justice. ... [Add the rest of your text here]"""

# Create a TextBlob object
blob = TextBlob(text)

# Calculate word frequencies (in lowercase to avoid duplicates)
word_frequencies = Counter([word.lower() for word in blob.words])

# Score sentences based on the sum of word frequencies
sentence_scores = {}
for sentence in blob.sentences:
    # Sum frequencies only for words in the sentence
    sentence_scores[sentence] = sum(word_frequencies[word.lower()] for word in sentence.words)

# Sort sentences based on their score and select the top 5 sentences
summary_sentences = sorted(sentence_scores, key=sentence_scores.get, reverse=True)[:5]

# Display the summarized text
print("Summary:")
for sentence in summary_sentences:
    print(sentence)
# Out:
# Summary:
# Chhatrapati Shivaji Maharaj was born on February 19, 1630, at Shivneri Fort in Maharashtra,
# to Shahaji Bhonsle, a Maratha general, and Jijabai, who deeply influenced Shivaji with her teachings
# on dharma, bravery, and justice.
# ... [Add the rest of your text here]
